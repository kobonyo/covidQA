# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction import stop_words
from sklearn.feature_extraction.text import TfidfVectorizer
import os
from nltk.corpus import stopwords 
import nltk
import re
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity,euclidean_distances
# Out:
# C:\Users\uroot\anaconda3\envs\ml\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.feature_extraction.stop_words module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_extraction.text. Anything that cannot be imported from sklearn.feature_extraction.text is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
#nltk.download('stopwords')

# %%
stop = set(['?',',',':','@'])

# %%
ROOT = '../data/'

QA_dict = {}

# %%
os.listdir(ROOT)
# Out:
# ['CDC.xlsx',
#  'Coronavirus (COVID-19) frequently asked questions _ CDC.pdf',
#  'covidquestionsca.xlsx',
#  'EAC.xlsx',
#  'JHU.xlsx',
#  'MOHKE.xlsx',
#  'sources.txt',
#  'WHO.xlsx']

# %%
paths = [ROOT+d for d in os.listdir(ROOT) if d.endswith(".xlsx")]

# %%
paths
# Out:
# ['../data/CDC.xlsx',
#  '../data/covidquestionsca.xlsx',
#  '../data/EAC.xlsx',
#  '../data/JHU.xlsx',
#  '../data/MOHKE.xlsx',
#  '../data/WHO.xlsx']

# %%
data = [ pd.read_excel(p, names = ['q','a']) for p in paths]

# %%
QA = pd.DataFrame()

# %%
for d in data[:]:
    if d.shape[0]>0:
        print(d.shape)
        QA = pd.concat((QA,d),axis = 0)
# Out:
# (116, 2)
# (10, 2)
# (26, 2)
# (86, 2)
# (85, 2)

# %%
QA.shape
# Out:
# (323, 2)

# %%
QA.sample(10)
# Out:
#                                                      q  \
# 24   What should I do if I have had close contact w...
# 106       Can I take my dog to daycare or a groomer?\n
# 43   How much information about the movements of in...
# 19   What can I do to protect myself and prevent th...
# 82   How large does a meeting or event need to be i...
# 72                 Can women with COVID-19 breastfeed?
# 111  Can I travel to the United States with dogs or...
# 8           Why does it take long to develop a vaccine
# 45   While school’s out, limit time with older adul...
# 8                            How does COVID-19 spread?
#
#                                                      a
# 24   There is information for people who have had c...
# 106  Until we know more about how this virus a ects...
# 43   These decisions should be made with local publ...
# 19   Keep up to date on the latest COVID-19 hotspot...
# 82   High profile international sporting events suc...
# 72   Yes. Women with COVID-19 can breastfeed if the...
# 111  Please refer to CDC’s requirements for bringin...
# 8    Developing a vaccine takes time, in most cases...
# 45   Older adults and people who have serious under...
# 8    People can also catch COVID-19 if they breathe...

# %%
 snow = nltk.stem.SnowballStemmer('english')

# %%
def clean(q_a):
    temp = []
    snow = nltk.stem.SnowballStemmer('english')
    for sentence in q_a:
        sentence = str(sentence)
        sentence = sentence.lower()                 # Converting to lowercase
        cleanr = re.compile('<.*?>')
        sentence = re.sub(cleanr, ' ', sentence)        #Removing HTML tags
        sentence = re.sub(r'[?|!|\'|"|#]\d',r'',sentence)
        sentence = re.sub(r'[.|,|)|(|\|/]@',r' ',sentence)        #Removing Punctuations
        words = [snow.stem(word) for word in sentence.split() if word not in stop]   # Stemming and removing stopwords
        temp.append(words)
    q_a = temp  
    return q_a

# %%
def clean_col(c):
    sent = []
    for row in c:
        sequ = ''
        for word in row:
            sequ = sequ + ' ' + word
        sent.append(sequ)
    c = sent
    return c

# %%
q_new =  clean_col(clean(QA['q']))
a_new =  clean_col(clean(QA['a']))

# %%
QA['q_new'] =  q_new
QA['a_new'] = a_new

# %%
QA.head()
# Out:
#                                                    q  \
# 0                       What is a novel coronavirus?
# 1  Why is the disease being called coronavirus di...
# 2  Why might someone blame or avoid individuals a...
# 3  How can people help stop stigma related to COV...
# 4  Why do some state’s COVID-19 case numbers some...
#
#                                                    a  \
# 0  A novel coronavirus is a new coronavirus that ...
# 1  On February 11, 2020 the World Health Organiza...
# 2  People in the U.S. may be worried or anxious a...
# 3  People can ght stigma by providing social supp...
# 4  CDC’s overall case numbers are validated throu...
#
#                                                q_new  \
# 0                       what is a novel coronavirus?
# 1   whi is the diseas be call coronavirus diseas ...
# 2   whi might someon blame or avoid individu and ...
# 3   how can peopl help stop stigma relat to covid...
# 4   whi do some state covid-19 case number someti...
#
#                                                a_new
# 0   a novel coronavirus is a new coronavirus that...
# 1   on februari 11, 2020 the world health organ a...
# 2   peopl in the u.s. may be worri or anxious abo...
# 3   peopl can ght stigma by provid social support...
# 4   cdc overal case number are valid through a co...

# %%
w2v_data = QA['q_new']

# %%
w2v_data
# Out:
# 0                          what is a novel coronavirus?
# 1      whi is the diseas be call coronavirus diseas ...
# 2      whi might someon blame or avoid individu and ...
# 3      how can peopl help stop stigma relat to covid...
# 4      whi do some state covid-19 case number someti...
#                             ...
# 80     are smoker and tobacco user at higher risk of...
# 81     are smoker and tobacco user at higher risk of...
# 82     how larg doe a meet or event need to be in or...
# 83     how larg doe a meet or event need to be in or...
# 84     doe who recommend that all intern mass gather...
# Name: q_new, Length: 323, dtype: object

# %%
splitted = []
for row in w2v_data: 
    splitted.append([word for word in row.split()])

# %%
[[word for word in row.split()] for row in w2v_data]
# Out:
# [['what', 'is', 'a', 'novel', 'coronavirus?'],
#  ['whi',
#   'is',
#   'the',
#   'diseas',
#   'be',
#   'call',
#   'coronavirus',
#   'diseas',
#   '2019,',
#   'covid-19?'],
#  ['whi',
#   'might',
#   'someon',
#   'blame',
#   'or',
#   'avoid',
#   'individu',
#   'and',
#   'group',
#   '(creat',
#   'stigma)',
#   'becaus',
#   'of',
#   'covid-19?'],
#  ['how', 'can', 'peopl', 'help', 'stop', 'stigma', 'relat', 'to', 'covid-19?'],
#  ['whi',
#   'do',
#   'some',
#   'state',
#   'covid-19',
#   'case',
#   'number',
#   'sometim',
#   'di',
#   'er',
#   'from',
#   'what',
#   'is',
#   'post',
#   'on',
#   'cdc',
#   'website?'],
#  ['how',
#   'do',
#   'cdc',
#   'covid-19',
#   'case',
#   'number',
#   'compar',
#   'with',
#   'those',
#   'provid',
#   'by',
#   'the',
#   'world',
#   'health',
#   'organ',
#   '(who)',
#   'or'],
#  ['john', 'hopkins?'],
#  ['whi',
#   'do',
#   'the',
#   'number',
#   'of',
#   'case',
#   'for',
#   'previous',
#   'day',
#   'increase?'],
#  ['are',
#   'peopl',
#   'with',
#   'high',
#   'blood',
#   'pressur',
#   '(hypertension)',
#   'at',
#   'higher',
#   'risk',
#   'from',
#   'covid-19?'],
#  ['should',
#   'i',
#   'continu',
#   'to',
#   'take',
#   'my',
#   'blood',
#   'pressur',
#   'medication?'],
#  ['what', 'is', 'the', 'sourc', 'of', 'the', 'virus?'],
#  ['how', 'doe', 'the', 'virus', 'spread?'],
#  ['whi', 'are', 'we', 'see', 'a', 'rise', 'in', 'cases?'],
#  ['can',
#   'someon',
#   'who',
#   'has',
#   'had',
#   'covid-19',
#   'spread',
#   'the',
#   'ill',
#   'to',
#   'others?'],
#  ['can',
#   'someon',
#   'who',
#   'has',
#   'been',
#   'quarantin',
#   'for',
#   'covid-19',
#   'spread',
#   'the',
#   'ill',
#   'to',
#   'others?'],
#  ['can',
#   'the',
#   'virus',
#   'that',
#   'caus',
#   'covid-19',
#   'be',
#   'spread',
#   'through',
#   'food,',
#   'includ',
#   'restaur',
#   'take',
#   'out,',
#   'refriger',
#   'or',
#   'frozen',
#   'packag',
#   'food?'],
#  ['can',
#   'i',
#   'get',
#   'sick',
#   'with',
#   'covid-19',
#   'if',
#   'it',
#   'is',
#   'on',
#   'food?'],
#  ['will', 'warm', 'weather', 'stop', 'the', 'outbreak', 'of', 'covid-19?'],
#  ['what', 'is', 'communiti', 'spread?'],
#  ['what', 'temperatur', 'kill', 'the', 'virus', 'that', 'caus', 'covid-19?'],
#  ['can',
#   'mosquito',
#   'or',
#   'tick',
#   'spread',
#   'the',
#   'virus',
#   'that',
#   'caus',
#   'covid-19?'],
#  ['am', 'i', 'at', 'risk', 'for', 'covid-19', 'in', 'the', 'unit', 'states?'],
#  ['how',
#   'mani',
#   'case',
#   'have',
#   'been',
#   'report',
#   'in',
#   'the',
#   'unit',
#   'states?'],
#  ['how', 'can', 'i', 'help', 'protect', 'myself?'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'i',
#   'have',
#   'had',
#   'close',
#   'contact',
#   'with',
#   'someon',
#   'who',
#   'has',
#   'covid-19?'],
#  ['doe',
#   'cdc',
#   'recommend',
#   'the',
#   'use',
#   'of',
#   'facemask',
#   'or',
#   'face',
#   'cover',
#   'to',
#   'prevent',
#   'covid-19?'],
#  ['is',
#   'it',
#   'safe',
#   'to',
#   'get',
#   'care',
#   'for',
#   'my',
#   'other',
#   'medic',
#   'condit',
#   'dure',
#   'this',
#   'time?'],
#  ['am',
#   'i',
#   'at',
#   'risk',
#   'for',
#   'covid-19',
#   'from',
#   'mail,',
#   'packages,',
#   'or',
#   'products?'],
#  ['is', 'it', 'okay', 'for', 'me', 'to', 'donat', 'blood?'],
#  ['should',
#   'contact',
#   'len',
#   'wearer',
#   'take',
#   'special',
#   'precaut',
#   'to',
#   'prevent',
#   'covid-19?'],
#  ['what',
#   'is',
#   'the',
#   'risk',
#   'of',
#   'my',
#   'child',
#   'becom',
#   'sick',
#   'with',
#   'covid-19?'],
#  ['how',
#   'can',
#   'i',
#   'protect',
#   'my',
#   'child',
#   'from',
#   'covid-19',
#   'infection?'],
#  ['are',
#   'the',
#   'symptom',
#   'of',
#   'covid-19',
#   'di',
#   'erent',
#   'in',
#   'children',
#   'than',
#   'in',
#   'adults?'],
#  ['should', 'children', 'wear', 'masks?'],
#  ['how',
#   'do',
#   'i',
#   'prepar',
#   'my',
#   'children',
#   'in',
#   'case',
#   'of',
#   'covid-19',
#   'outbreak',
#   'in',
#   'our',
#   'community?'],
#  ['what',
#   'step',
#   'should',
#   'parent',
#   'take',
#   'to',
#   'protect',
#   'children',
#   'dure',
#   'a',
#   'communiti',
#   'outbreak?'],
#  ['what',
#   'is',
#   'multisystem',
#   'in',
#   'ammatori',
#   'syndrom',
#   'in',
#   'children',
#   '(mis-c)',
#   'and',
#   'who',
#   'is',
#   'at',
#   'risk?'],
#  ['while',
#   'school',
#   'out,',
#   'can',
#   'my',
#   'child',
#   'hang',
#   'out',
#   'with',
#   'their',
#   'friends?'],
#  ['while',
#   'school',
#   'out,',
#   'how',
#   'can',
#   'i',
#   'help',
#   'my',
#   'child',
#   'continu',
#   'learning?'],
#  ['while', 'school', 'out,', 'will', 'kid', 'have', 'access', 'to', 'meals?'],
#  ['while',
#   'school',
#   'out,',
#   'how',
#   'can',
#   'i',
#   'keep',
#   'my',
#   'famili',
#   'healthy?'],
#  ['while',
#   'school',
#   'out,',
#   'how',
#   'can',
#   'i',
#   'keep',
#   'my',
#   'famili',
#   'healthy?'],
#  ['while',
#   'school',
#   'out,',
#   'how',
#   'can',
#   'i',
#   'keep',
#   'my',
#   'famili',
#   'healthy?'],
#  ['while',
#   'school',
#   'out,',
#   'how',
#   'can',
#   'i',
#   'keep',
#   'my',
#   'famili',
#   'healthy?'],
#  ['while',
#   'school',
#   'out,',
#   'how',
#   'can',
#   'i',
#   'keep',
#   'my',
#   'famili',
#   'healthy?'],
#  ['while',
#   'school',
#   'out,',
#   'limit',
#   'time',
#   'with',
#   'older',
#   'adults,',
#   'includ',
#   'relatives,',
#   'and',
#   'peopl',
#   'with',
#   'chronic',
#   'medic',
#   'conditions.'],
#  ['is',
#   'my',
#   'child',
#   'with',
#   'an',
#   'under',
#   'medic',
#   'condit',
#   'or',
#   'special',
#   'healthcar',
#   'need',
#   'at',
#   'higher',
#   'risk',
#   'for',
#   'sever',
#   'ill',
#   'from',
#   'covid-19?'],
#  ['what',
#   'addit',
#   'step',
#   'should',
#   'famili',
#   'that',
#   'have',
#   'a',
#   'child',
#   'with',
#   'an',
#   'under',
#   'medic',
#   'condit',
#   'or',
#   'special',
#   'health',
#   'care',
#   'need',
#   'take?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'if',
#   'my',
#   'child',
#   'has',
#   'di',
#   'culti',
#   'adjust',
#   'to',
#   'new',
#   'routin',
#   'and',
#   'follow',
#   'recommendations?'],
#  ['how', 'can', 'my', 'famili', 'cope', 'with', 'the', 'ad', 'stress?'],
#  ['what',
#   'if',
#   'my',
#   'child',
#   'or',
#   'someon',
#   'els',
#   'in',
#   'the',
#   'home',
#   'is',
#   'sick',
#   'with',
#   'symptom',
#   'of',
#   'covid-19?'],
#  ['what',
#   'if',
#   'my',
#   'child',
#   'symptom',
#   'of',
#   'their',
#   'under',
#   'medic',
#   'condit',
#   'or',
#   'complex,',
#   'chronic',
#   'medic',
#   'condit',
#   'get',
#   'worse?'],
#  ['what', 'if', 'my', 'child', 'need', 'to', 'go', 'to', 'the', 'hospital?'],
#  ['how', 'can', 'my', 'famili', 'and', 'i', 'prepar', 'for', 'covid-19?'],
#  ['what',
#   'step',
#   'can',
#   'my',
#   'famili',
#   'take',
#   'to',
#   'reduc',
#   'our',
#   'risk',
#   'of',
#   'get',
#   'covid-19?'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'someon',
#   'in',
#   'my',
#   'hous',
#   'get',
#   'sick',
#   'with',
#   'covid-19?'],
#  ['when', 'to', 'seek', 'emerg', 'medic', 'attent'],
#  ['how',
#   'can',
#   'i',
#   'prepar',
#   'in',
#   'case',
#   'my',
#   'child',
#   'school,',
#   'child',
#   'care',
#   'facility,',
#   'or',
#   'univers',
#   'is',
#   'dismissed?'],
#  ['how', 'can', 'i', 'prepar', 'for', 'covid-19', 'at', 'work?'],
#  ['should',
#   'i',
#   'use',
#   'soap',
#   'and',
#   'water',
#   'or',
#   'a',
#   'hand',
#   'sanit',
#   'to',
#   'protect',
#   'against',
#   'covid-19?'],
#  ['what',
#   'clean',
#   'product',
#   'should',
#   'i',
#   'use',
#   'to',
#   'protect',
#   'against',
#   'covid-19?'],
#  ['should',
#   'i',
#   'make',
#   'my',
#   'own',
#   'hand',
#   'sanit',
#   'if',
#   'i',
#   "can't",
#   'nd',
#   'it',
#   'in',
#   'the',
#   'stores?'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'there',
#   'is',
#   'an',
#   'outbreak',
#   'in',
#   'my',
#   'community?'],
#  ['will',
#   'school',
#   'be',
#   'dismiss',
#   'if',
#   'there',
#   'is',
#   'an',
#   'outbreak',
#   'in',
#   'my',
#   'community?'],
#  ['should',
#   'i',
#   'go',
#   'to',
#   'work',
#   'if',
#   'there',
#   'is',
#   'an',
#   'outbreak',
#   'in',
#   'my',
#   'community?'],
#  ['will',
#   'busi',
#   'and',
#   'school',
#   'close',
#   'or',
#   'stay',
#   'close',
#   'in',
#   'my',
#   'communiti',
#   'and',
#   'for',
#   'how',
#   'long?',
#   'will',
#   'there',
#   'be',
#   'a',
#   '“stay',
#   'at',
#   'home”',
#   'or',
#   '“shelter',
#   'in',
#   'place”',
#   'order',
#   'in',
#   'my',
#   'community?'],
#  ['can',
#   'cdc',
#   'tell',
#   'me',
#   'or',
#   'my',
#   'employ',
#   'when',
#   'it',
#   'is',
#   'safe',
#   'for',
#   'me',
#   'to',
#   'go',
#   'back',
#   'to',
#   'work/school',
#   'after',
#   'recov',
#   'from',
#   'or',
#   'be',
#   'expos',
#   'to',
#   'covid-19?'],
#  ['what',
#   'are',
#   'the',
#   'symptom',
#   'and',
#   'complic',
#   'that',
#   'covid-19',
#   'can',
#   'cause?'],
#  ['is',
#   'it',
#   'possibl',
#   'to',
#   'have',
#   'the',
#   'flu',
#   'and',
#   'covid-19',
#   'at',
#   'the',
#   'same',
#   'time?'],
#  ['should', 'i', 'be', 'test', 'for', 'covid-19?'],
#  ['where', 'can', 'i', 'get', 'test', 'for', 'covid-19?'],
#  ['can',
#   'a',
#   'person',
#   'test',
#   'negat',
#   'and',
#   'later',
#   'test',
#   'posit',
#   'for',
#   'covid-19?'],
#  ['what',
#   'kind',
#   'of',
#   'test',
#   'is',
#   'be',
#   'use',
#   'to',
#   'diagnos',
#   'if',
#   'i',
#   'have',
#   'covid-19?'],
#  ['what',
#   'is',
#   'antibodi',
#   'testing?',
#   'and',
#   'can',
#   'i',
#   'be',
#   'test',
#   'use',
#   'this',
#   'method?'],
#  ['if',
#   'i',
#   'have',
#   'recov',
#   'from',
#   'covid-19,',
#   'will',
#   'i',
#   'be',
#   'immun',
#   'to',
#   'it?'],
#  ['who',
#   'is',
#   'at',
#   'higher',
#   'risk',
#   'for',
#   'serious',
#   'ill',
#   'from',
#   'covid-19?'],
#  ['what',
#   'should',
#   'peopl',
#   'at',
#   'higher',
#   'risk',
#   'of',
#   'serious',
#   'ill',
#   'with',
#   'covid-19',
#   'do?'],
#  ['how',
#   'were',
#   'the',
#   'under',
#   'condit',
#   'for',
#   'peopl',
#   'consid',
#   'higher',
#   'risk',
#   'of',
#   'serious',
#   'ill',
#   'with',
#   'covid-19',
#   'selected?'],
#  ['are',
#   'there',
#   'ani',
#   'medic',
#   'i',
#   'should',
#   'avoid',
#   'take',
#   'if',
#   'i',
#   'have',
#   'covid-19?'],
#  ['what',
#   'about',
#   'under',
#   'medic',
#   'condit',
#   'that',
#   'are',
#   'not',
#   'includ',
#   'on',
#   'this',
#   'list?'],
#  ['what', 'doe', 'a', 'well-control', 'health', 'condit', 'mean?'],
#  ['what', 'doe', 'more', 'sever', 'ill', 'mean?'],
#  ['are', 'peopl', 'with', 'disabl', 'at', 'higher', 'risk?'],
#  ['are',
#   'peopl',
#   'with',
#   'high',
#   'blood',
#   'pressur',
#   '(hypertension)',
#   'at',
#   'higher',
#   'risk',
#   'from',
#   'covid-19?'],
#  ['am',
#   'i',
#   'at',
#   'risk',
#   'if',
#   'i',
#   'go',
#   'to',
#   'a',
#   'funer',
#   'or',
#   'visit',
#   'servic',
#   'for',
#   'someon',
#   'who',
#   'die',
#   'of',
#   'covid-19?'],
#  ['am',
#   'i',
#   'at',
#   'risk',
#   'if',
#   'i',
#   'touch',
#   'someon',
#   'who',
#   'die',
#   'of',
#   'covid-19',
#   'after',
#   'they',
#   'have',
#   'pass',
#   'away?'],
#  ['what',
#   'do',
#   'funer',
#   'home',
#   'worker',
#   'need',
#   'to',
#   'know',
#   'about',
#   'handl',
#   'deced',
#   'who',
#   'had',
#   'covid-19?'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'my',
#   'famili',
#   'member',
#   'die',
#   'from',
#   'covid-19',
#   'while',
#   'overseas?'],
#  ['my',
#   'famili',
#   'member',
#   'die',
#   'from',
#   'covid-19',
#   'while',
#   'overseas.',
#   'what',
#   'are',
#   'the',
#   'requir',
#   'for',
#   'return',
#   'the',
#   'bodi',
#   'to',
#   'the',
#   'unit',
#   'states?'],
#  ['what', 'is', 'cdc', 'do', 'about', 'covid-19?'],
#  ['what',
#   'is',
#   'the',
#   'di',
#   'erenc',
#   'between',
#   'clean',
#   'and',
#   'disinfecting?'],
#  ['is',
#   'it',
#   'safe',
#   'to',
#   'vacuum',
#   'in',
#   'a',
#   'school,',
#   'business,',
#   'or',
#   'communiti',
#   'facil',
#   'after',
#   'someon',
#   'with',
#   'suspect',
#   'or',
#   'concovid-19',
#   'has',
#   'been',
#   'present?'],
#  ['what',
#   'is',
#   'routin',
#   'cleaning?',
#   'how',
#   'frequent',
#   'should',
#   'facil',
#   'be',
#   'clean',
#   'to',
#   'reduc',
#   'the',
#   'potenti',
#   'spread',
#   'of',
#   'covid-19?'],
#  ['is',
#   'clean',
#   'alon',
#   'e',
#   'ectiv',
#   'against',
#   'the',
#   'virus',
#   'that',
#   'caus',
#   'covid-19?'],
#  ['who', 'should', 'clean', 'and', 'disinfect', 'communiti', 'spaces?'],
#  ['how',
#   'long',
#   'do',
#   'compani',
#   'need',
#   'to',
#   'close',
#   'for',
#   'disinfect',
#   'after',
#   'an',
#   'exposure?',
#   'how',
#   'long',
#   'befor',
#   'other',
#   'worker',
#   'can',
#   'come',
#   'back',
#   'to',
#   'work?'],
#  ['how',
#   'e',
#   'ectiv',
#   'are',
#   'altern',
#   'disinfect',
#   'methods,',
#   'such',
#   'as',
#   'ultrason',
#   'waves,',
#   'high',
#   'intens',
#   'uv',
#   'radiation,',
#   'and',
#   'led',
#   'blue',
#   'light?'],
#  ['should',
#   'outdoor',
#   'playgrounds,',
#   'like',
#   'those',
#   'at',
#   'school',
#   'or',
#   'in',
#   'parks,',
#   'be',
#   'clean',
#   'and',
#   'disinfect',
#   'to',
#   'prevent',
#   'covid-19?'],
#  ['can',
#   'sanit',
#   'tunnel',
#   'be',
#   'use',
#   'at',
#   'build',
#   'entranc',
#   'or',
#   'exit',
#   'to',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'covid-19?'],
#  ['can',
#   'i',
#   'get',
#   'covid-19',
#   'from',
#   'my',
#   'pet',
#   'or',
#   'other',
#   'animals?'],
#  ['do', 'i', 'need', 'to', 'get', 'my', 'pet', 'test', 'for', 'covid-19?'],
#  ['can',
#   'anim',
#   'carri',
#   'the',
#   'virus',
#   'that',
#   'caus',
#   'covid-19',
#   'on',
#   'their',
#   'skin',
#   'or',
#   'fur?'],
#  ['should',
#   'i',
#   'avoid',
#   'contact',
#   'with',
#   'pet',
#   'or',
#   'other',
#   'anim',
#   'if',
#   'i',
#   'am',
#   'sick',
#   'with',
#   'covid-19?'],
#  ['what', 'anim', 'can', 'get', 'covid-19?'],
#  ['should', 'i', 'worri', 'about', 'my', 'pet', 'cat?'],
#  ['can', 'i', 'walk', 'my', 'dog?'],
#  ['can', 'i', 'take', 'my', 'dog', 'to', 'daycar', 'or', 'a', 'groomer?'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'my',
#   'pet',
#   'get',
#   'sick',
#   'and',
#   'i',
#   'think',
#   'it',
#   'covid-19?'],
#  ['whi',
#   'are',
#   'anim',
#   'be',
#   'test',
#   'when',
#   'mani',
#   'peopl',
#   "can't",
#   'get',
#   'tested?'],
#  ['are', 'pet', 'from', 'a', 'shelter', 'safe', 'to', 'adopt?'],
#  ['what', 'about', 'import', 'anim', 'or', 'anim', 'products?'],
#  ['can',
#   'i',
#   'travel',
#   'to',
#   'the',
#   'unit',
#   'state',
#   'with',
#   'dog',
#   'or',
#   'import',
#   'dog',
#   'into',
#   'the',
#   'unit',
#   'state',
#   'dure',
#   'the',
#   'covid-19',
#   'outbreak?'],
#  ['what',
#   'precaut',
#   'should',
#   'be',
#   'taken',
#   'for',
#   'anim',
#   'that',
#   'have',
#   'recent',
#   'been',
#   'import',
#   'from',
#   'outsid',
#   'the',
#   'unit',
#   'state',
#   '(for',
#   'example,',
#   'by',
#   'shelters,',
#   'rescues,',
#   'or',
#   'as',
#   'person',
#   'pets)?'],
#  ['what', 'is', 'communiti', 'mitigation?'],
#  ['what', 'are', 'communiti', 'mitig', 'action', 'for', 'covid-19?'],
#  ['who', 'is', 'involv', 'in', 'communiti', 'mitig', 'actions?'],
#  ['was', 'covid-19', 'creat', 'in', 'a', 'laboratori', 'by', 'accident?'],
#  ['can', 'you', 'contract', 'covid-19', 'more', 'than', 'once?'],
#  ['what', 'is', 'differ', 'about', 'the', 'virus'],
#  ['whi', 'is', 'the', 'virus', 'so', 'quick', 'to', 'spread'],
#  ['nan'],
#  ['nan'],
#  ['is', 'there', 'ani', 'concern', 'mosquito', 'cari', 'the', 'virus?'],
#  ['whi', 'do', 'some', 'peopl', 'with', 'covid-19', 'need', 'a', 'ventil'],
#  ['whi', 'doe', 'it', 'take', 'long', 'to', 'develop', 'a', 'vaccin'],
#  ['is', 'there', 'vaccin', 'availabele?'],
#  ['what', 'is', 'a', 'coronavirus?'],
#  ['what', 'doe', 'covid-19', 'stand', 'for?'],
#  ['what', 'is', 'covid-19?'],
#  ['what', 'are', 'the', 'symptom', 'of', 'covid-19?'],
#  ['who', 'is', 'most', 'at', 'risk', 'of', 'catch', 'covid-19?'],
#  ['do', 'i', 'need', 'to', 'worri', 'about', 'my', 'children?'],
#  ['how', 'doe', 'covid-19', 'spread?'],
#  ['how', 'can', 'i', 'prevent', 'myself', 'from', 'get', 'infected?'],
#  ['which', 'hygien', 'measur', 'are', 'effective?'],
#  ['should',
#   'i',
#   'wear',
#   'a',
#   'facemask',
#   'to',
#   'protect',
#   'myself',
#   'against',
#   'the',
#   'virus?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'other',
#   'if',
#   'i',
#   'am',
#   'sick',
#   'or',
#   'have',
#   'test',
#   'posit',
#   'with',
#   'the',
#   'coronavirus',
#   'disease?'],
#  ['can',
#   'someon',
#   'who',
#   'is',
#   'releas',
#   'from',
#   'covid-19',
#   'quarantin',
#   'still',
#   'spread',
#   'the',
#   'disease?'],
#  ['how',
#   'can',
#   'i',
#   'contribut',
#   'to',
#   'avoid',
#   'stigmatis',
#   'peopl',
#   'relat',
#   'to',
#   'covid-19?'],
#  ['nan'],
#  ['is', 'there', 'a', 'treatment', 'for', 'covid-19?'],
#  ['is', 'there', 'a', 'vaccin', 'against', 'covid-19?'],
#  ['must', 'i', 'fear', 'covid', '19?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'ensur',
#   'my',
#   'workplac',
#   'is',
#   'safe',
#   'for',
#   'me',
#   'and',
#   'my',
#   'colleague?'],
#  ['is',
#   'it',
#   'safe',
#   'to',
#   'use',
#   'public',
#   'transport',
#   '(dalla',
#   'dalla',
#   'or',
#   'matatu)',
#   'with',
#   'regard',
#   'to',
#   'covid-19?'],
#  ['can', 'i', 'attend', 'the', 'church', 'service?'],
#  ['are',
#   'african',
#   'less',
#   'at',
#   'risk',
#   'of',
#   'contract',
#   'the',
#   'covid-19',
#   'compar',
#   'to',
#   'other',
#   'races?'],
#  ['doe',
#   'eat',
#   'bush',
#   'meat',
#   'pose',
#   'a',
#   'risk',
#   'for',
#   'covid-19',
#   'infections?'],
#  ['are',
#   'patient',
#   'who',
#   'recov',
#   'from',
#   'covid-19',
#   'immun',
#   'against',
#   'the',
#   'virus?'],
#  ['how', 'safe', 'are', 'good', 'from', 'china?'],
#  ['can',
#   'i',
#   'get',
#   'covid-19',
#   'through',
#   'second-hand',
#   'cloth',
#   'from',
#   'overseas?'],
#  ['what',
#   'is',
#   'the',
#   'differ',
#   'between',
#   'the',
#   'averag',
#   'death',
#   'rate',
#   'among',
#   'confirm',
#   'case',
#   'and',
#   'the',
#   'overal',
#   'averag',
#   'death',
#   'rate?'],
#  ['what', 'is', 'a', 'coronavirus?'],
#  ['whi', 'is', 'it', 'call', 'a', 'coronavirus?'],
#  ['what', 'sever', 'diseas', 'are', 'caus', 'by', 'coronaviruses?'],
#  ['what', 'the', 'differ', 'between', 'coronavirus', 'and', 'covid-19?'],
#  ['what',
#   'symptom',
#   'do',
#   'coronavirus',
#   'typic',
#   'cause?',
#   'how',
#   'sever',
#   'are',
#   'the',
#   'symptom',
#   'in',
#   'the',
#   'current',
#   'outbreak?'],
#  ['doe', 'the', 'virus', 'affect', 'the', 'sens', 'of', 'taste?'],
#  ['whi', 'doe', 'covid-19', 'caus', 'short', 'of', 'breath?'],
#  ['is',
#   'the',
#   'loss',
#   'of',
#   'smell',
#   'an',
#   'earli',
#   'coronavirus',
#   'indicator?'],
#  ['even',
#   'for',
#   'peopl',
#   'who',
#   'are',
#   'mild',
#   'ill',
#   'or',
#   'moder',
#   'ill,',
#   'they',
#   'may',
#   'have',
#   'some',
#   'degre',
#   'of',
#   'impact',
#   'on',
#   'their',
#   'lung',
#   'that',
#   'could',
#   'caus',
#   'short',
#   'of',
#   'breath.',
#   'is',
#   'that',
#   'right?'],
#  ['when', 'and', 'how', 'should', 'i', 'seek', 'medic', 'attention?'],
#  ['how', 'are', 'coronavirus', 'transmit', 'between', 'people?'],
#  ['what',
#   'is',
#   'known',
#   'about',
#   'young',
#   'children',
#   'and',
#   'whether',
#   'they',
#   'are',
#   'carrier',
#   'and',
#   'can',
#   'transmit',
#   'the',
#   'virus?'],
#  ['what',
#   'percentag',
#   'of',
#   'the',
#   'popul',
#   'will',
#   'becom',
#   'infect',
#   'with',
#   'covid-19?'],
#  ['of',
#   'those',
#   'infected,',
#   'what',
#   'percentag',
#   'will',
#   'requir',
#   'hospitalization?',
#   'and',
#   'what',
#   'percentag',
#   'will',
#   'requir',
#   'care',
#   'in',
#   'an',
#   'intens',
#   'care',
#   'unit',
#   '(icu)?'],
#  ['are',
#   'there',
#   'differ',
#   '“species”',
#   'of',
#   'coronavirus',
#   'like',
#   'there',
#   'are',
#   'for',
#   'ebola?'],
#  ['what', 'doe', 'this', 'mean', 'for', 'a', 'vaccine?'],
#  ['when',
#   'peopl',
#   'are',
#   'asymptomatic,',
#   'can',
#   'they',
#   'spread',
#   'the',
#   'virus?'],
#  ['how',
#   'long',
#   'is',
#   'an',
#   'asymptomat',
#   'carrier',
#   'shed',
#   'the',
#   'virus?',
#   'can',
#   'they',
#   'have',
#   'it',
#   'for',
#   'life,',
#   'like',
#   'the',
#   'herp',
#   'virus?'],
#  ['what', 'doe', '“recovered”', 'mean?'],
#  ['what',
#   'is',
#   'the',
#   'possibl',
#   'of',
#   'reinfect',
#   'after',
#   'you',
#   'have',
#   'recov',
#   'from',
#   'covid-19?'],
#  ['is',
#   'there',
#   'a',
#   'differ',
#   'between',
#   'hospital-acquir',
#   'covid',
#   'and',
#   'community-acquir',
#   'covid?'],
#  ['is',
#   'there',
#   'evid',
#   'of',
#   'a',
#   'heighten',
#   'risk',
#   'to',
#   'pregnant',
#   'women?'],
#  ['what',
#   'is',
#   'known',
#   'about',
#   'how',
#   'this',
#   'virus',
#   'respond',
#   'to',
#   'warm',
#   'weather',
#   'and',
#   'the',
#   'potenti',
#   'for',
#   '“seasonality?”'],
#  ['there',
#   'have',
#   'been',
#   'more',
#   'case',
#   'in',
#   'the',
#   'northern',
#   'hemispher',
#   'than',
#   'the',
#   'southern',
#   'hemisphere.',
#   'what',
#   'doe',
#   'that',
#   'mean?'],
#  ['are', 'covid', 'toe', 'relat', 'to', 'blood', 'clotting?'],
#  ['what',
#   'make',
#   'this',
#   'upper',
#   'respiratori',
#   'infect',
#   'caus',
#   'by',
#   'an',
#   'rna',
#   'virus',
#   'ani',
#   'differ',
#   'from',
#   'hundr',
#   'of',
#   'other',
#   'upper',
#   'respiratori',
#   'infect',
#   'caus',
#   'by',
#   'rna',
#   'viruses?'],
#  ['are',
#   'some',
#   'group',
#   'at',
#   'a',
#   'higher',
#   'risk',
#   'for',
#   'sever',
#   'covid-19',
#   'illness?'],
#  ['are',
#   'there',
#   'option',
#   'for',
#   'support',
#   'senior',
#   'who',
#   "don't",
#   'have',
#   'onlin',
#   'access',
#   'for',
#   'get',
#   'groceri',
#   'delivered?'],
#  ['should',
#   'peopl',
#   'on',
#   'immunosuppress',
#   'drug',
#   'stop',
#   'take',
#   'their',
#   'medications?'],
#  ['will',
#   'peopl',
#   'who',
#   'are',
#   'on',
#   'these',
#   'drug',
#   'or',
#   'who',
#   'have',
#   'immunosuppress',
#   'condit',
#   'be',
#   'stuck',
#   'at',
#   'home',
#   'much',
#   'longer',
#   'than',
#   'other',
#   'who',
#   'may',
#   'be',
#   'abl',
#   'to',
#   'come',
#   'back',
#   'out',
#   'when',
#   'restrict',
#   'lift?'],
#  ['how',
#   'is',
#   'covid-19',
#   'is',
#   'impact',
#   'peopl',
#   'without',
#   'spleens?',
#   '(with',
#   'certain',
#   'bacteri',
#   'diseases,',
#   'peopl',
#   'without',
#   'spleen',
#   'can',
#   'get',
#   'veri',
#   'sever',
#   'infections.)'],
#  ['are',
#   'women',
#   'take',
#   'oral',
#   'contracept',
#   'more',
#   'at',
#   'risk',
#   'from',
#   'blood',
#   'clot',
#   'from',
#   'covid-19?'],
#  ['when', 'is', 'test', 'important?'],
#  ['what',
#   'doe',
#   'test',
#   'tell',
#   'us',
#   'about',
#   'the',
#   'rate',
#   'of',
#   'mortal',
#   'and',
#   'spread',
#   'of',
#   'the',
#   'virus?'],
#  ['whi',
#   "aren't",
#   'there',
#   'enough',
#   'test',
#   'avail',
#   'and',
#   'will',
#   'this',
#   'change?'],
#  ['whi',
#   'are',
#   'there',
#   'reagent',
#   'shortag',
#   'that',
#   'are',
#   'impact',
#   'testing?'],
#  ['is',
#   'the',
#   'current',
#   'spike',
#   'in',
#   'case',
#   'a',
#   'result',
#   'of',
#   'increas',
#   'test',
#   'or',
#   'becaus',
#   'the',
#   'virus',
#   'is',
#   'still',
#   'spreading?',
#   'when',
#   'can',
#   'we',
#   'expect',
#   'to',
#   'see',
#   'the',
#   'curv',
#   'flatten?'],
#  ['can',
#   'the',
#   'covid-19',
#   'test',
#   'tell',
#   'the',
#   'differ',
#   'between',
#   'someon',
#   'with',
#   'an',
#   'activ',
#   'infect',
#   'and',
#   'someon',
#   'who',
#   'was',
#   'infect',
#   'in',
#   'the',
#   'past?'],
#  ['what',
#   'is',
#   'the',
#   'differ',
#   'between',
#   'molecular',
#   'test',
#   'and',
#   'serolog',
#   'tests?',
#   'can',
#   'serolog',
#   'test',
#   'be',
#   'use',
#   'in',
#   'place',
#   'of',
#   'molecular',
#   'tests?'],
#  ['if',
#   'you',
#   'are',
#   'test',
#   'and',
#   'the',
#   'test',
#   'is',
#   'negative,',
#   'do',
#   'you',
#   'still',
#   'have',
#   'to',
#   'be',
#   'quarantined?'],
#  ['are', 'fals', 'negat', 'a', 'problem', 'with', 'covid', 'tests?'],
#  ['with',
#   'limit',
#   'test',
#   'available,',
#   'how',
#   'do',
#   'we',
#   'tell',
#   'peopl',
#   'to',
#   'assum',
#   'they',
#   'have',
#   'coronavirus,',
#   'or',
#   'have',
#   'been',
#   'expos',
#   'to',
#   'it,',
#   'without',
#   'panick',
#   'them?'],
#  ['should',
#   'we',
#   'be',
#   'test',
#   'first',
#   'respond',
#   'befor',
#   'they',
#   'start',
#   'their',
#   'work',
#   'day?'],
#  ['how',
#   'much',
#   'inform',
#   'about',
#   'the',
#   'movement',
#   'of',
#   'individu',
#   'who',
#   'test',
#   'posit',
#   'should',
#   'we',
#   'share,',
#   'and',
#   'how',
#   'do',
#   'we',
#   'avoid',
#   'caus',
#   'a',
#   'panic',
#   'by',
#   'peopl',
#   'think',
#   'they',
#   'may',
#   'have',
#   'been',
#   'exposed?'],
#  ['what',
#   'are',
#   'the',
#   'dispar',
#   'in',
#   'test',
#   'for',
#   'margin',
#   'communiti',
#   'and',
#   'how',
#   'can',
#   'we',
#   'address',
#   'them?'],
#  ['how', 'can', 'i', 'protect', 'myself', 'against', 'coronaviruses?'],
#  ['is', 'hand', 'sanit', 'effect', 'to', 'protect', 'against', 'coronavirus?'],
#  ['how', 'long', 'doe', 'the', 'virus', 'stay', 'on', 'your', 'clothes?'],
#  ['clean',
#   'produc',
#   'brought',
#   'home',
#   'from',
#   'the',
#   'groceri',
#   'store:',
#   'should',
#   'you',
#   'do',
#   'anyth',
#   'differ',
#   'or',
#   'use',
#   'ani',
#   'particular',
#   'clean',
#   'products?'],
#  ['is',
#   'takeout',
#   'food',
#   'safe?',
#   'what',
#   'precaut',
#   'should',
#   'peopl',
#   'take?'],
#  ['is', 'the', 'public', 'water', 'suppli', 'safe', 'from', 'the', 'virus?'],
#  ['if',
#   'two',
#   'peopl',
#   'are',
#   'positive,',
#   'can',
#   'they',
#   'quarantin',
#   'togeth',
#   'or',
#   'do',
#   'they',
#   'have',
#   'to',
#   'be',
#   'separated?'],
#  ['is',
#   'it',
#   'correct',
#   'that',
#   'if',
#   'someon',
#   'in',
#   'your',
#   'home',
#   'is',
#   'ill',
#   'then',
#   'you',
#   'should',
#   'also',
#   'be',
#   'stay',
#   'at',
#   'home?'],
#  ['can',
#   'you',
#   'avoid',
#   'the',
#   'virus',
#   'by',
#   'drink',
#   'warm',
#   'water',
#   'everi',
#   '15',
#   'minutes?'],
#  ['there',
#   'a',
#   'holding-your-breath',
#   'test',
#   'sweep',
#   'the',
#   'internet:',
#   'is',
#   'it',
#   'true',
#   'that',
#   'if',
#   'you',
#   'can',
#   'hold',
#   'your',
#   'breath,',
#   'you',
#   'know',
#   'that',
#   'you',
#   'do',
#   'or',
#   'you',
#   'do',
#   'not',
#   'have',
#   'covid-19?'],
#  ['should',
#   'the',
#   'general',
#   'public',
#   'cover',
#   'their',
#   'face',
#   'with',
#   'bandana',
#   'or',
#   'other',
#   'makeshift',
#   'masks?'],
#  ['is',
#   'there',
#   'offici',
#   'guidanc',
#   'on',
#   'the',
#   'efficaci',
#   'of',
#   'diy',
#   'face',
#   'mask',
#   'and',
#   'can',
#   'these',
#   'be',
#   'donat',
#   'for',
#   'use',
#   'in',
#   'health',
#   'care',
#   'settings?'],
#  ['are',
#   'there',
#   'accept',
#   'design',
#   'of',
#   'ppe',
#   'that',
#   'local',
#   'manufactur',
#   'and',
#   'hobbyist',
#   '3d',
#   'printer',
#   'can',
#   'creat',
#   'for',
#   'medic',
#   'staff?'],
#  ['if',
#   'someon',
#   'goe',
#   'for',
#   'a',
#   'jog',
#   'through',
#   'a',
#   'neighborhood',
#   'where',
#   'there',
#   'might',
#   'be',
#   'a',
#   'patient',
#   'with',
#   'novel',
#   'coronavirus,',
#   'are',
#   'they',
#   'at',
#   'risk?'],
#  ['how',
#   'should',
#   'i',
#   'help',
#   'a',
#   'friend,',
#   'neighbor,',
#   'or',
#   'famili',
#   'member',
#   'who',
#   'is',
#   'ill?'],
#  ['will', 'i', 'get', 'sick', 'if', 'i', 'help', 'care', 'for', 'them?'],
#  ['are', 'my', 'pet', 'at', 'risk', 'of', 'get', 'sick?'],
#  ['how',
#   'much',
#   'food',
#   'should',
#   'peopl',
#   'have',
#   'on',
#   'hand?',
#   'are',
#   'there',
#   'concern',
#   'about',
#   'the',
#   'food',
#   'suppli',
#   'at',
#   'this',
#   'point?'],
#  ['can',
#   'the',
#   'virus',
#   'travel',
#   'to',
#   'the',
#   'lower',
#   'lung',
#   'dure',
#   'deep',
#   'breath',
#   'exercises,',
#   'such',
#   'as',
#   'dure',
#   'yoga?'],
#  ['doe',
#   'a',
#   'person',
#   'blood',
#   'type',
#   'affect',
#   'how',
#   'infecti',
#   'or',
#   'sick',
#   'that',
#   'person',
#   'may',
#   'become?'],
#  ['can', 'you', 'get', 'covid-19', 'from', 'second-hand', 'smoke?'],
#  ['doe',
#   'prone',
#   'bodi',
#   'posit',
#   'help',
#   'veri',
#   'sever',
#   'ill',
#   'coronavirus',
#   'patient',
#   'in',
#   'the',
#   'intens',
#   'care',
#   'unit?'],
#  ['wet',
#   'market',
#   'in',
#   'china',
#   'are',
#   'wide',
#   'believ',
#   'to',
#   'be',
#   'a',
#   'sourc',
#   'of',
#   'new',
#   'infections,',
#   'includ',
#   'coronavirus.',
#   'should',
#   'they',
#   'be',
#   'shut',
#   'down?'],
#  ['can',
#   'peopl',
#   'expect',
#   'to',
#   'be',
#   'immun',
#   'onc',
#   "they'v",
#   'had',
#   'the',
#   'virus?',
#   'can',
#   'the',
#   'virus',
#   '“reactivate?”'],
#  ['are',
#   'peopl',
#   'who',
#   'are',
#   'sicker',
#   'like',
#   'to',
#   'be',
#   'more',
#   'immun',
#   'than',
#   'those',
#   'who',
#   "didn't",
#   'feel',
#   'ani',
#   'symptom',
#   'at',
#   'all?'],
#  ['is',
#   'it',
#   'possibl',
#   'that',
#   'some',
#   'peopl',
#   'may',
#   'be',
#   'expos',
#   'and',
#   'have',
#   'mild',
#   'ill',
#   'but',
#   'still',
#   'produc',
#   'antibodi',
#   'that',
#   'could',
#   'prevent',
#   'them',
#   'from',
#   'get',
#   'a',
#   'more',
#   'serious',
#   'infection?'],
#  ['mani',
#   'of',
#   'these',
#   'virus',
#   'come',
#   'from',
#   'bats,',
#   'but',
#   'bat',
#   'are',
#   'immun',
#   'to',
#   'them.',
#   'can',
#   'we',
#   'learn',
#   'someth',
#   'from',
#   'bat',
#   'that',
#   'would',
#   'help',
#   'us',
#   'fight',
#   'the',
#   'virus',
#   'in',
#   'humans?'],
#  ['what', 'treatment', 'are', 'there', 'for', 'coronaviruses?'],
#  ['what',
#   'progress',
#   'is',
#   'be',
#   'made',
#   'on',
#   'therapi',
#   'or',
#   'treatment',
#   'for',
#   'covid-19?'],
#  ['is',
#   'there',
#   'evid',
#   'for',
#   'use',
#   'hydroxychloroquin',
#   'as',
#   'a',
#   'treatment',
#   'for',
#   'covid-19?'],
#  ['we',
#   'have',
#   'a',
#   'new',
#   'flu',
#   'vaccin',
#   'everi',
#   'year',
#   'with',
#   'a',
#   'new',
#   'strain.',
#   'whi',
#   'is',
#   'it',
#   'so',
#   'hard',
#   'to',
#   'get',
#   'a',
#   'coronavirus',
#   'vaccine?'],
#  ['is',
#   'interferon',
#   'alfa',
#   '2b',
#   'an',
#   'effect',
#   'treatment?',
#   'should',
#   'we',
#   'be',
#   'encourag',
#   'our',
#   'medic',
#   'communiti',
#   'to',
#   'obtain',
#   'this?'],
#  ['what', 'are', 'random', 'control', 'trials?'],
#  ['whi',
#   'is',
#   'the',
#   'world',
#   'respons',
#   'to',
#   'covid-19',
#   'so',
#   'much',
#   'greater',
#   'than',
#   'the',
#   'respons',
#   'to',
#   'other',
#   'outbreak',
#   'like',
#   'h1n1',
#   'or',
#   'sars?'],
#  ['what',
#   'metric',
#   'should',
#   'citi',
#   'be',
#   'look',
#   'at',
#   'to',
#   'understand',
#   'the',
#   'real-tim',
#   'spread',
#   'and',
#   'anticip',
#   'the',
#   'time',
#   'of',
#   'the',
#   'surge?'],
#  ['for',
#   'busi',
#   'that',
#   'remain',
#   'open,',
#   'what',
#   'are',
#   'best',
#   'practic',
#   'they',
#   'should',
#   'be',
#   'use',
#   'to',
#   'stop',
#   'the',
#   'spread?'],
#  ['what',
#   'should',
#   'we',
#   'do',
#   'to',
#   'protect',
#   'employe',
#   'at',
#   'busi',
#   'that',
#   'are',
#   'still',
#   'open,',
#   'like',
#   'groceri',
#   'stores,',
#   'hotels,',
#   'and',
#   'restaurants?'],
#  ['doe',
#   'the',
#   'scienc',
#   'support',
#   'limit',
#   'the',
#   'number',
#   'of',
#   'peopl',
#   'in',
#   'groceri',
#   'store',
#   'at',
#   'one',
#   'time?'],
#  ['how',
#   'do',
#   'we',
#   'get',
#   'through',
#   'to',
#   'the',
#   'youth',
#   'who',
#   'feel',
#   'they',
#   'are',
#   'immun',
#   'to',
#   'the',
#   'diseas',
#   'or',
#   'not',
#   'affect',
#   'by',
#   'it?'],
#  ['whi',
#   "aren't",
#   'we',
#   'see',
#   'human',
#   'temperatur',
#   'monitor',
#   'in',
#   'public',
#   'place',
#   'like',
#   'airports,',
#   'hospitals,',
#   'groceri',
#   'stores,',
#   'warehouses,',
#   'etc.?'],
#  ['are', 'resid', 'of', 'homeless', 'shelter', 'a', 'vulner', 'population?'],
#  ['what', 'is', 'a', 'coronavirus?'],
#  ['what', 'is', 'a', 'coronavirus?'],
#  ['what', 'is', 'covid-19?'],
#  ['what', 'are', 'the', 'symptom', 'of', 'covid-19?'],
#  ['what', 'are', 'the', 'symptom', 'of', 'covid-19?'],
#  ['what', 'are', 'the', 'symptom', 'of', 'covid-19?'],
#  ['what', 'are', 'the', 'symptom', 'of', 'covid-19?'],
#  ['how', 'doe', 'covid-19', 'spread?'],
#  ['how', 'doe', 'covid-19', 'spread?'],
#  ['can',
#   'the',
#   'virus',
#   'that',
#   'caus',
#   'covid-19',
#   'be',
#   'transmit',
#   'through',
#   'the',
#   'air?'],
#  ['can',
#   'covid-19',
#   'be',
#   'caught',
#   'from',
#   'a',
#   'person',
#   'who',
#   'has',
#   'no',
#   'symptoms?'],
#  ['can',
#   'covid-19',
#   'be',
#   'caught',
#   'from',
#   'a',
#   'person',
#   'who',
#   'has',
#   'no',
#   'symptoms?'],
#  ['can',
#   'i',
#   'catch',
#   'covid-19',
#   'from',
#   'the',
#   'fece',
#   'of',
#   'someon',
#   'with',
#   'the',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'and',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'and',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'and',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'and',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'and',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'and',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'and',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'andprotect',
#   'measur',
#   'for',
#   'person',
#   'who',
#   'are',
#   'in',
#   'or',
#   'have',
#   'recent',
#   'visit',
#   '(past',
#   '14',
#   'days)',
#   'area',
#   'where',
#   'covid-19',
#   'is',
#   'spread',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['protect',
#   'measur',
#   'for',
#   'person',
#   'who',
#   'are',
#   'in',
#   'or',
#   'have',
#   'recent',
#   'visit',
#   '(past',
#   '14',
#   'days)',
#   'area',
#   'where',
#   'covid-19',
#   'is',
#   'spread'],
#  ['how', 'like', 'am', 'i', 'to', 'catch', 'covid-19?'],
#  ['how', 'like', 'am', 'i', 'to', 'catch', 'covid-19?'],
#  ['how', 'like', 'am', 'i', 'to', 'catch', 'covid-19?'],
#  ['should', 'i', 'worri', 'about', 'covid-19'],
#  ['should', 'i', 'worri', 'about', 'covid-19'],
#  ['who', 'is', 'at', 'risk', 'of', 'develop', 'sever', 'illness?'],
#  ['are',
#   'antibiot',
#   'effect',
#   'in',
#   'prevent',
#   'or',
#   'treat',
#   'the',
#   'covid-19?'],
#  ['are',
#   'antibiot',
#   'effect',
#   'in',
#   'prevent',
#   'or',
#   'treat',
#   'the',
#   'covid-19?'],
#  ['are',
#   'there',
#   'ani',
#   'medicin',
#   'or',
#   'therapi',
#   'that',
#   'can',
#   'prevent',
#   'or',
#   'cure',
#   'covid-19?'],
#  ['are',
#   'there',
#   'ani',
#   'medicin',
#   'or',
#   'therapi',
#   'that',
#   'can',
#   'prevent',
#   'or',
#   'cure',
#   'covid-19?'],
#  ['is',
#   'there',
#   'a',
#   'vaccine,',
#   'drug',
#   'or',
#   'treatment',
#   'for',
#   'covid-19?'],
#  ['is',
#   'there',
#   'a',
#   'vaccine,',
#   'drug',
#   'or',
#   'treatment',
#   'for',
#   'covid-19?'],
#  ['is',
#   'there',
#   'a',
#   'vaccine,',
#   'drug',
#   'or',
#   'treatment',
#   'for',
#   'covid-19?'],
#  ['is',
#   'there',
#   'a',
#   'vaccine,',
#   'drug',
#   'or',
#   'treatment',
#   'for',
#   'covid-19?'],
#  ['is', 'covid-19', 'the', 'same', 'as', 'sars?'],
#  ['is', 'covid-19', 'the', 'same', 'as', 'sars?'],
#  ['should', 'i', 'wear', 'a', 'mask', 'to', 'protect', 'myself'],
#  ['should', 'i', 'wear', 'a', 'mask', 'to', 'protect', 'myself'],
#  ['should', 'i', 'wear', 'a', 'mask', 'to', 'protect', 'myself'],
#  ['how',
#   'to',
#   'put',
#   'on,',
#   'use,',
#   'take',
#   'off',
#   'and',
#   'dispos',
#   'of',
#   'a',
#   'mask?'],
#  ['how',
#   'to',
#   'put',
#   'on,',
#   'use,',
#   'take',
#   'off',
#   'and',
#   'dispos',
#   'of',
#   'a',
#   'mask?'],
#  ['how', 'long', 'is', 'the', 'incub', 'period', 'for', 'covid-19?'],
#  ['how', 'long', 'is', 'the', 'incub', 'period', 'for', 'covid-19?'],
#  ['can',
#   'human',
#   'be',
#   'infect',
#   'with',
#   'the',
#   'covid-19',
#   'from',
#   'an',
#   'anim',
#   'source?'],
#  ['can',
#   'human',
#   'be',
#   'infect',
#   'with',
#   'the',
#   'covid-19',
#   'from',
#   'an',
#   'anim',
#   'source?'],
#  ['can',
#   'human',
#   'be',
#   'infect',
#   'with',
#   'the',
#   'covid-19',
#   'from',
#   'an',
#   'anim',
#   'source?'],
#  ['can',
#   'human',
#   'be',
#   'infect',
#   'with',
#   'the',
#   'covid-19',
#   'from',
#   'an',
#   'anim',
#   'source?'],
#  ['can',
#   'human',
#   'be',
#   'infect',
#   'with',
#   'the',
#   'covid-19',
#   'from',
#   'an',
#   'anim',
#   'source?'],
#  ['can', 'i', 'catch', 'covid-19', 'from', 'my', 'pet?'],
#  ['can', 'i', 'catch', 'covid-19', 'from', 'my', 'pet?'],
#  ['how', 'long', 'doe', 'the', 'virus', 'surviv', 'on', 'surfaces?'],
#  ['how', 'long', 'doe', 'the', 'virus', 'surviv', 'on', 'surfaces?'],
#  ['how', 'long', 'doe', 'the', 'virus', 'surviv', 'on', 'surfaces?'],
#  ['is',
#   'it',
#   'safe',
#   'to',
#   'receiv',
#   'a',
#   'packag',
#   'from',
#   'ani',
#   'area',
#   'where',
#   'covid-19',
#   'has',
#   'been',
#   'reported?'],
#  ['is', 'there', 'anyth', 'i', 'should', 'not', 'do?'],
#  ['is', 'there', 'anyth', 'i', 'should', 'not', 'do?'],
#  ['is', 'there', 'anyth', 'i', 'should', 'not', 'do?'],
#  ['is', 'the', 'sourc', 'caus', 'covid-19', 'known?'],
#  ['how', 'did', 'the', 'first', 'human', 'sars-cov-2', 'infect', 'occur?'],
#  ['how', 'did', 'the', 'first', 'human', 'sars-cov-2', 'infect', 'occur?'],
#  ['how', 'did', 'the', 'first', 'human', 'sars-cov-2', 'infect', 'occur?'],
#  ['is', 'covid-19', 'airborne?'],
#  ['are', 'pregnant', 'women', 'at', 'higher', 'risk', 'from', 'covid-19?'],
#  ['are', 'pregnant', 'women', 'at', 'higher', 'risk', 'from', 'covid-19?'],
#  ["i'm",
#   'pregnant.',
#   'how',
#   'can',
#   'i',
#   'protect',
#   'myself',
#   'against',
#   'covid-19?'],
#  ["i'm",
#   'pregnant.',
#   'how',
#   'can',
#   'i',
#   'protect',
#   'myself',
#   'against',
#   'covid-19?'],
#  ['should', 'pregnant', 'women', 'be', 'test', 'for', 'covid-19?'],
#  ['can',
#   'covid-19',
#   'be',
#   'pass',
#   'from',
#   'a',
#   'woman',
#   'to',
#   'her',
#   'unborn',
#   'baby?'],
#  ['what',
#   'care',
#   'should',
#   'be',
#   'avail',
#   'dure',
#   'pregnanc',
#   'and',
#   'childbirth?'],
#  ['do',
#   'pregnant',
#   'women',
#   'with',
#   'suspect',
#   'or',
#   'confirm',
#   'covid-19',
#   'need',
#   'to',
#   'give',
#   'birth',
#   'by',
#   'ceasarean',
#   'section?'],
#  ['can', 'women', 'with', 'covid-19', 'breastfeed?'],
#  ['can',
#   'i',
#   'touch',
#   'and',
#   'hold',
#   'my',
#   'newborn',
#   'babi',
#   'if',
#   'i',
#   'have',
#   'covid-19?'],
#  ['how', 'are', 'covid-19', 'and', 'influenza', 'virus', 'similar?'],
#  ['how', 'are', 'covid-19', 'and', 'influenza', 'virus', 'similar?'],
#  ['how', 'are', 'covid-19', 'and', 'influenza', 'virus', 'different?'],
#  ['how', 'are', 'covid-19', 'and', 'influenza', 'virus', 'different?'],
#  ['how', 'are', 'covid-19', 'and', 'influenza', 'virus', 'different?'],
#  ['what',
#   'medic',
#   'intervent',
#   'are',
#   'avail',
#   'for',
#   'covid-19',
#   'and',
#   'influenza',
#   'viruses?'],
#  ['are',
#   'smoker',
#   'and',
#   'tobacco',
#   'user',
#   'at',
#   'higher',
#   'risk',
#   'of',
#   'covid-19',
#   'infection?'],
#  ['are',
#   'smoker',
#   'and',
#   'tobacco',
#   'user',
#   'at',
#   'higher',
#   'risk',
#   'of',
#   'covid-19',
#   'infection?'],
#  ['how',
#   'larg',
#   'doe',
#   'a',
#   'meet',
#   'or',
#   'event',
#   'need',
#   'to',
#   'be',
#   'in',
#   'order',
#   'to',
#   'be',
#   'a',
#   '“mass',
#   'gathering”?'],
#  ['how',
#   'larg',
#   'doe',
#   'a',
#   'meet',
#   'or',
#   'event',
#   'need',
#   'to',
#   'be',
#   'in',
#   'order',
#   'to',
#   'be',
#   'a',
#   '“mass',
#   'gathering”?'],
#  ['doe',
#   'who',
#   'recommend',
#   'that',
#   'all',
#   'intern',
#   'mass',
#   'gather',
#   'be',
#   'cancel',
#   'becaus',
#   'of',
#   'covid-19?']]

# %%
splitted
# Out:
# [['what', 'is', 'a', 'novel', 'coronavirus?'],
#  ['whi',
#   'is',
#   'the',
#   'diseas',
#   'be',
#   'call',
#   'coronavirus',
#   'diseas',
#   '2019,',
#   'covid-19?'],
#  ['whi',
#   'might',
#   'someon',
#   'blame',
#   'or',
#   'avoid',
#   'individu',
#   'and',
#   'group',
#   '(creat',
#   'stigma)',
#   'becaus',
#   'of',
#   'covid-19?'],
#  ['how', 'can', 'peopl', 'help', 'stop', 'stigma', 'relat', 'to', 'covid-19?'],
#  ['whi',
#   'do',
#   'some',
#   'state',
#   'covid-19',
#   'case',
#   'number',
#   'sometim',
#   'di',
#   'er',
#   'from',
#   'what',
#   'is',
#   'post',
#   'on',
#   'cdc',
#   'website?'],
#  ['how',
#   'do',
#   'cdc',
#   'covid-19',
#   'case',
#   'number',
#   'compar',
#   'with',
#   'those',
#   'provid',
#   'by',
#   'the',
#   'world',
#   'health',
#   'organ',
#   '(who)',
#   'or'],
#  ['john', 'hopkins?'],
#  ['whi',
#   'do',
#   'the',
#   'number',
#   'of',
#   'case',
#   'for',
#   'previous',
#   'day',
#   'increase?'],
#  ['are',
#   'peopl',
#   'with',
#   'high',
#   'blood',
#   'pressur',
#   '(hypertension)',
#   'at',
#   'higher',
#   'risk',
#   'from',
#   'covid-19?'],
#  ['should',
#   'i',
#   'continu',
#   'to',
#   'take',
#   'my',
#   'blood',
#   'pressur',
#   'medication?'],
#  ['what', 'is', 'the', 'sourc', 'of', 'the', 'virus?'],
#  ['how', 'doe', 'the', 'virus', 'spread?'],
#  ['whi', 'are', 'we', 'see', 'a', 'rise', 'in', 'cases?'],
#  ['can',
#   'someon',
#   'who',
#   'has',
#   'had',
#   'covid-19',
#   'spread',
#   'the',
#   'ill',
#   'to',
#   'others?'],
#  ['can',
#   'someon',
#   'who',
#   'has',
#   'been',
#   'quarantin',
#   'for',
#   'covid-19',
#   'spread',
#   'the',
#   'ill',
#   'to',
#   'others?'],
#  ['can',
#   'the',
#   'virus',
#   'that',
#   'caus',
#   'covid-19',
#   'be',
#   'spread',
#   'through',
#   'food,',
#   'includ',
#   'restaur',
#   'take',
#   'out,',
#   'refriger',
#   'or',
#   'frozen',
#   'packag',
#   'food?'],
#  ['can',
#   'i',
#   'get',
#   'sick',
#   'with',
#   'covid-19',
#   'if',
#   'it',
#   'is',
#   'on',
#   'food?'],
#  ['will', 'warm', 'weather', 'stop', 'the', 'outbreak', 'of', 'covid-19?'],
#  ['what', 'is', 'communiti', 'spread?'],
#  ['what', 'temperatur', 'kill', 'the', 'virus', 'that', 'caus', 'covid-19?'],
#  ['can',
#   'mosquito',
#   'or',
#   'tick',
#   'spread',
#   'the',
#   'virus',
#   'that',
#   'caus',
#   'covid-19?'],
#  ['am', 'i', 'at', 'risk', 'for', 'covid-19', 'in', 'the', 'unit', 'states?'],
#  ['how',
#   'mani',
#   'case',
#   'have',
#   'been',
#   'report',
#   'in',
#   'the',
#   'unit',
#   'states?'],
#  ['how', 'can', 'i', 'help', 'protect', 'myself?'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'i',
#   'have',
#   'had',
#   'close',
#   'contact',
#   'with',
#   'someon',
#   'who',
#   'has',
#   'covid-19?'],
#  ['doe',
#   'cdc',
#   'recommend',
#   'the',
#   'use',
#   'of',
#   'facemask',
#   'or',
#   'face',
#   'cover',
#   'to',
#   'prevent',
#   'covid-19?'],
#  ['is',
#   'it',
#   'safe',
#   'to',
#   'get',
#   'care',
#   'for',
#   'my',
#   'other',
#   'medic',
#   'condit',
#   'dure',
#   'this',
#   'time?'],
#  ['am',
#   'i',
#   'at',
#   'risk',
#   'for',
#   'covid-19',
#   'from',
#   'mail,',
#   'packages,',
#   'or',
#   'products?'],
#  ['is', 'it', 'okay', 'for', 'me', 'to', 'donat', 'blood?'],
#  ['should',
#   'contact',
#   'len',
#   'wearer',
#   'take',
#   'special',
#   'precaut',
#   'to',
#   'prevent',
#   'covid-19?'],
#  ['what',
#   'is',
#   'the',
#   'risk',
#   'of',
#   'my',
#   'child',
#   'becom',
#   'sick',
#   'with',
#   'covid-19?'],
#  ['how',
#   'can',
#   'i',
#   'protect',
#   'my',
#   'child',
#   'from',
#   'covid-19',
#   'infection?'],
#  ['are',
#   'the',
#   'symptom',
#   'of',
#   'covid-19',
#   'di',
#   'erent',
#   'in',
#   'children',
#   'than',
#   'in',
#   'adults?'],
#  ['should', 'children', 'wear', 'masks?'],
#  ['how',
#   'do',
#   'i',
#   'prepar',
#   'my',
#   'children',
#   'in',
#   'case',
#   'of',
#   'covid-19',
#   'outbreak',
#   'in',
#   'our',
#   'community?'],
#  ['what',
#   'step',
#   'should',
#   'parent',
#   'take',
#   'to',
#   'protect',
#   'children',
#   'dure',
#   'a',
#   'communiti',
#   'outbreak?'],
#  ['what',
#   'is',
#   'multisystem',
#   'in',
#   'ammatori',
#   'syndrom',
#   'in',
#   'children',
#   '(mis-c)',
#   'and',
#   'who',
#   'is',
#   'at',
#   'risk?'],
#  ['while',
#   'school',
#   'out,',
#   'can',
#   'my',
#   'child',
#   'hang',
#   'out',
#   'with',
#   'their',
#   'friends?'],
#  ['while',
#   'school',
#   'out,',
#   'how',
#   'can',
#   'i',
#   'help',
#   'my',
#   'child',
#   'continu',
#   'learning?'],
#  ['while', 'school', 'out,', 'will', 'kid', 'have', 'access', 'to', 'meals?'],
#  ['while',
#   'school',
#   'out,',
#   'how',
#   'can',
#   'i',
#   'keep',
#   'my',
#   'famili',
#   'healthy?'],
#  ['while',
#   'school',
#   'out,',
#   'how',
#   'can',
#   'i',
#   'keep',
#   'my',
#   'famili',
#   'healthy?'],
#  ['while',
#   'school',
#   'out,',
#   'how',
#   'can',
#   'i',
#   'keep',
#   'my',
#   'famili',
#   'healthy?'],
#  ['while',
#   'school',
#   'out,',
#   'how',
#   'can',
#   'i',
#   'keep',
#   'my',
#   'famili',
#   'healthy?'],
#  ['while',
#   'school',
#   'out,',
#   'how',
#   'can',
#   'i',
#   'keep',
#   'my',
#   'famili',
#   'healthy?'],
#  ['while',
#   'school',
#   'out,',
#   'limit',
#   'time',
#   'with',
#   'older',
#   'adults,',
#   'includ',
#   'relatives,',
#   'and',
#   'peopl',
#   'with',
#   'chronic',
#   'medic',
#   'conditions.'],
#  ['is',
#   'my',
#   'child',
#   'with',
#   'an',
#   'under',
#   'medic',
#   'condit',
#   'or',
#   'special',
#   'healthcar',
#   'need',
#   'at',
#   'higher',
#   'risk',
#   'for',
#   'sever',
#   'ill',
#   'from',
#   'covid-19?'],
#  ['what',
#   'addit',
#   'step',
#   'should',
#   'famili',
#   'that',
#   'have',
#   'a',
#   'child',
#   'with',
#   'an',
#   'under',
#   'medic',
#   'condit',
#   'or',
#   'special',
#   'health',
#   'care',
#   'need',
#   'take?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'if',
#   'my',
#   'child',
#   'has',
#   'di',
#   'culti',
#   'adjust',
#   'to',
#   'new',
#   'routin',
#   'and',
#   'follow',
#   'recommendations?'],
#  ['how', 'can', 'my', 'famili', 'cope', 'with', 'the', 'ad', 'stress?'],
#  ['what',
#   'if',
#   'my',
#   'child',
#   'or',
#   'someon',
#   'els',
#   'in',
#   'the',
#   'home',
#   'is',
#   'sick',
#   'with',
#   'symptom',
#   'of',
#   'covid-19?'],
#  ['what',
#   'if',
#   'my',
#   'child',
#   'symptom',
#   'of',
#   'their',
#   'under',
#   'medic',
#   'condit',
#   'or',
#   'complex,',
#   'chronic',
#   'medic',
#   'condit',
#   'get',
#   'worse?'],
#  ['what', 'if', 'my', 'child', 'need', 'to', 'go', 'to', 'the', 'hospital?'],
#  ['how', 'can', 'my', 'famili', 'and', 'i', 'prepar', 'for', 'covid-19?'],
#  ['what',
#   'step',
#   'can',
#   'my',
#   'famili',
#   'take',
#   'to',
#   'reduc',
#   'our',
#   'risk',
#   'of',
#   'get',
#   'covid-19?'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'someon',
#   'in',
#   'my',
#   'hous',
#   'get',
#   'sick',
#   'with',
#   'covid-19?'],
#  ['when', 'to', 'seek', 'emerg', 'medic', 'attent'],
#  ['how',
#   'can',
#   'i',
#   'prepar',
#   'in',
#   'case',
#   'my',
#   'child',
#   'school,',
#   'child',
#   'care',
#   'facility,',
#   'or',
#   'univers',
#   'is',
#   'dismissed?'],
#  ['how', 'can', 'i', 'prepar', 'for', 'covid-19', 'at', 'work?'],
#  ['should',
#   'i',
#   'use',
#   'soap',
#   'and',
#   'water',
#   'or',
#   'a',
#   'hand',
#   'sanit',
#   'to',
#   'protect',
#   'against',
#   'covid-19?'],
#  ['what',
#   'clean',
#   'product',
#   'should',
#   'i',
#   'use',
#   'to',
#   'protect',
#   'against',
#   'covid-19?'],
#  ['should',
#   'i',
#   'make',
#   'my',
#   'own',
#   'hand',
#   'sanit',
#   'if',
#   'i',
#   "can't",
#   'nd',
#   'it',
#   'in',
#   'the',
#   'stores?'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'there',
#   'is',
#   'an',
#   'outbreak',
#   'in',
#   'my',
#   'community?'],
#  ['will',
#   'school',
#   'be',
#   'dismiss',
#   'if',
#   'there',
#   'is',
#   'an',
#   'outbreak',
#   'in',
#   'my',
#   'community?'],
#  ['should',
#   'i',
#   'go',
#   'to',
#   'work',
#   'if',
#   'there',
#   'is',
#   'an',
#   'outbreak',
#   'in',
#   'my',
#   'community?'],
#  ['will',
#   'busi',
#   'and',
#   'school',
#   'close',
#   'or',
#   'stay',
#   'close',
#   'in',
#   'my',
#   'communiti',
#   'and',
#   'for',
#   'how',
#   'long?',
#   'will',
#   'there',
#   'be',
#   'a',
#   '“stay',
#   'at',
#   'home”',
#   'or',
#   '“shelter',
#   'in',
#   'place”',
#   'order',
#   'in',
#   'my',
#   'community?'],
#  ['can',
#   'cdc',
#   'tell',
#   'me',
#   'or',
#   'my',
#   'employ',
#   'when',
#   'it',
#   'is',
#   'safe',
#   'for',
#   'me',
#   'to',
#   'go',
#   'back',
#   'to',
#   'work/school',
#   'after',
#   'recov',
#   'from',
#   'or',
#   'be',
#   'expos',
#   'to',
#   'covid-19?'],
#  ['what',
#   'are',
#   'the',
#   'symptom',
#   'and',
#   'complic',
#   'that',
#   'covid-19',
#   'can',
#   'cause?'],
#  ['is',
#   'it',
#   'possibl',
#   'to',
#   'have',
#   'the',
#   'flu',
#   'and',
#   'covid-19',
#   'at',
#   'the',
#   'same',
#   'time?'],
#  ['should', 'i', 'be', 'test', 'for', 'covid-19?'],
#  ['where', 'can', 'i', 'get', 'test', 'for', 'covid-19?'],
#  ['can',
#   'a',
#   'person',
#   'test',
#   'negat',
#   'and',
#   'later',
#   'test',
#   'posit',
#   'for',
#   'covid-19?'],
#  ['what',
#   'kind',
#   'of',
#   'test',
#   'is',
#   'be',
#   'use',
#   'to',
#   'diagnos',
#   'if',
#   'i',
#   'have',
#   'covid-19?'],
#  ['what',
#   'is',
#   'antibodi',
#   'testing?',
#   'and',
#   'can',
#   'i',
#   'be',
#   'test',
#   'use',
#   'this',
#   'method?'],
#  ['if',
#   'i',
#   'have',
#   'recov',
#   'from',
#   'covid-19,',
#   'will',
#   'i',
#   'be',
#   'immun',
#   'to',
#   'it?'],
#  ['who',
#   'is',
#   'at',
#   'higher',
#   'risk',
#   'for',
#   'serious',
#   'ill',
#   'from',
#   'covid-19?'],
#  ['what',
#   'should',
#   'peopl',
#   'at',
#   'higher',
#   'risk',
#   'of',
#   'serious',
#   'ill',
#   'with',
#   'covid-19',
#   'do?'],
#  ['how',
#   'were',
#   'the',
#   'under',
#   'condit',
#   'for',
#   'peopl',
#   'consid',
#   'higher',
#   'risk',
#   'of',
#   'serious',
#   'ill',
#   'with',
#   'covid-19',
#   'selected?'],
#  ['are',
#   'there',
#   'ani',
#   'medic',
#   'i',
#   'should',
#   'avoid',
#   'take',
#   'if',
#   'i',
#   'have',
#   'covid-19?'],
#  ['what',
#   'about',
#   'under',
#   'medic',
#   'condit',
#   'that',
#   'are',
#   'not',
#   'includ',
#   'on',
#   'this',
#   'list?'],
#  ['what', 'doe', 'a', 'well-control', 'health', 'condit', 'mean?'],
#  ['what', 'doe', 'more', 'sever', 'ill', 'mean?'],
#  ['are', 'peopl', 'with', 'disabl', 'at', 'higher', 'risk?'],
#  ['are',
#   'peopl',
#   'with',
#   'high',
#   'blood',
#   'pressur',
#   '(hypertension)',
#   'at',
#   'higher',
#   'risk',
#   'from',
#   'covid-19?'],
#  ['am',
#   'i',
#   'at',
#   'risk',
#   'if',
#   'i',
#   'go',
#   'to',
#   'a',
#   'funer',
#   'or',
#   'visit',
#   'servic',
#   'for',
#   'someon',
#   'who',
#   'die',
#   'of',
#   'covid-19?'],
#  ['am',
#   'i',
#   'at',
#   'risk',
#   'if',
#   'i',
#   'touch',
#   'someon',
#   'who',
#   'die',
#   'of',
#   'covid-19',
#   'after',
#   'they',
#   'have',
#   'pass',
#   'away?'],
#  ['what',
#   'do',
#   'funer',
#   'home',
#   'worker',
#   'need',
#   'to',
#   'know',
#   'about',
#   'handl',
#   'deced',
#   'who',
#   'had',
#   'covid-19?'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'my',
#   'famili',
#   'member',
#   'die',
#   'from',
#   'covid-19',
#   'while',
#   'overseas?'],
#  ['my',
#   'famili',
#   'member',
#   'die',
#   'from',
#   'covid-19',
#   'while',
#   'overseas.',
#   'what',
#   'are',
#   'the',
#   'requir',
#   'for',
#   'return',
#   'the',
#   'bodi',
#   'to',
#   'the',
#   'unit',
#   'states?'],
#  ['what', 'is', 'cdc', 'do', 'about', 'covid-19?'],
#  ['what',
#   'is',
#   'the',
#   'di',
#   'erenc',
#   'between',
#   'clean',
#   'and',
#   'disinfecting?'],
#  ['is',
#   'it',
#   'safe',
#   'to',
#   'vacuum',
#   'in',
#   'a',
#   'school,',
#   'business,',
#   'or',
#   'communiti',
#   'facil',
#   'after',
#   'someon',
#   'with',
#   'suspect',
#   'or',
#   'concovid-19',
#   'has',
#   'been',
#   'present?'],
#  ['what',
#   'is',
#   'routin',
#   'cleaning?',
#   'how',
#   'frequent',
#   'should',
#   'facil',
#   'be',
#   'clean',
#   'to',
#   'reduc',
#   'the',
#   'potenti',
#   'spread',
#   'of',
#   'covid-19?'],
#  ['is',
#   'clean',
#   'alon',
#   'e',
#   'ectiv',
#   'against',
#   'the',
#   'virus',
#   'that',
#   'caus',
#   'covid-19?'],
#  ['who', 'should', 'clean', 'and', 'disinfect', 'communiti', 'spaces?'],
#  ['how',
#   'long',
#   'do',
#   'compani',
#   'need',
#   'to',
#   'close',
#   'for',
#   'disinfect',
#   'after',
#   'an',
#   'exposure?',
#   'how',
#   'long',
#   'befor',
#   'other',
#   'worker',
#   'can',
#   'come',
#   'back',
#   'to',
#   'work?'],
#  ['how',
#   'e',
#   'ectiv',
#   'are',
#   'altern',
#   'disinfect',
#   'methods,',
#   'such',
#   'as',
#   'ultrason',
#   'waves,',
#   'high',
#   'intens',
#   'uv',
#   'radiation,',
#   'and',
#   'led',
#   'blue',
#   'light?'],
#  ['should',
#   'outdoor',
#   'playgrounds,',
#   'like',
#   'those',
#   'at',
#   'school',
#   'or',
#   'in',
#   'parks,',
#   'be',
#   'clean',
#   'and',
#   'disinfect',
#   'to',
#   'prevent',
#   'covid-19?'],
#  ['can',
#   'sanit',
#   'tunnel',
#   'be',
#   'use',
#   'at',
#   'build',
#   'entranc',
#   'or',
#   'exit',
#   'to',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'covid-19?'],
#  ['can',
#   'i',
#   'get',
#   'covid-19',
#   'from',
#   'my',
#   'pet',
#   'or',
#   'other',
#   'animals?'],
#  ['do', 'i', 'need', 'to', 'get', 'my', 'pet', 'test', 'for', 'covid-19?'],
#  ['can',
#   'anim',
#   'carri',
#   'the',
#   'virus',
#   'that',
#   'caus',
#   'covid-19',
#   'on',
#   'their',
#   'skin',
#   'or',
#   'fur?'],
#  ['should',
#   'i',
#   'avoid',
#   'contact',
#   'with',
#   'pet',
#   'or',
#   'other',
#   'anim',
#   'if',
#   'i',
#   'am',
#   'sick',
#   'with',
#   'covid-19?'],
#  ['what', 'anim', 'can', 'get', 'covid-19?'],
#  ['should', 'i', 'worri', 'about', 'my', 'pet', 'cat?'],
#  ['can', 'i', 'walk', 'my', 'dog?'],
#  ['can', 'i', 'take', 'my', 'dog', 'to', 'daycar', 'or', 'a', 'groomer?'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'my',
#   'pet',
#   'get',
#   'sick',
#   'and',
#   'i',
#   'think',
#   'it',
#   'covid-19?'],
#  ['whi',
#   'are',
#   'anim',
#   'be',
#   'test',
#   'when',
#   'mani',
#   'peopl',
#   "can't",
#   'get',
#   'tested?'],
#  ['are', 'pet', 'from', 'a', 'shelter', 'safe', 'to', 'adopt?'],
#  ['what', 'about', 'import', 'anim', 'or', 'anim', 'products?'],
#  ['can',
#   'i',
#   'travel',
#   'to',
#   'the',
#   'unit',
#   'state',
#   'with',
#   'dog',
#   'or',
#   'import',
#   'dog',
#   'into',
#   'the',
#   'unit',
#   'state',
#   'dure',
#   'the',
#   'covid-19',
#   'outbreak?'],
#  ['what',
#   'precaut',
#   'should',
#   'be',
#   'taken',
#   'for',
#   'anim',
#   'that',
#   'have',
#   'recent',
#   'been',
#   'import',
#   'from',
#   'outsid',
#   'the',
#   'unit',
#   'state',
#   '(for',
#   'example,',
#   'by',
#   'shelters,',
#   'rescues,',
#   'or',
#   'as',
#   'person',
#   'pets)?'],
#  ['what', 'is', 'communiti', 'mitigation?'],
#  ['what', 'are', 'communiti', 'mitig', 'action', 'for', 'covid-19?'],
#  ['who', 'is', 'involv', 'in', 'communiti', 'mitig', 'actions?'],
#  ['was', 'covid-19', 'creat', 'in', 'a', 'laboratori', 'by', 'accident?'],
#  ['can', 'you', 'contract', 'covid-19', 'more', 'than', 'once?'],
#  ['what', 'is', 'differ', 'about', 'the', 'virus'],
#  ['whi', 'is', 'the', 'virus', 'so', 'quick', 'to', 'spread'],
#  ['nan'],
#  ['nan'],
#  ['is', 'there', 'ani', 'concern', 'mosquito', 'cari', 'the', 'virus?'],
#  ['whi', 'do', 'some', 'peopl', 'with', 'covid-19', 'need', 'a', 'ventil'],
#  ['whi', 'doe', 'it', 'take', 'long', 'to', 'develop', 'a', 'vaccin'],
#  ['is', 'there', 'vaccin', 'availabele?'],
#  ['what', 'is', 'a', 'coronavirus?'],
#  ['what', 'doe', 'covid-19', 'stand', 'for?'],
#  ['what', 'is', 'covid-19?'],
#  ['what', 'are', 'the', 'symptom', 'of', 'covid-19?'],
#  ['who', 'is', 'most', 'at', 'risk', 'of', 'catch', 'covid-19?'],
#  ['do', 'i', 'need', 'to', 'worri', 'about', 'my', 'children?'],
#  ['how', 'doe', 'covid-19', 'spread?'],
#  ['how', 'can', 'i', 'prevent', 'myself', 'from', 'get', 'infected?'],
#  ['which', 'hygien', 'measur', 'are', 'effective?'],
#  ['should',
#   'i',
#   'wear',
#   'a',
#   'facemask',
#   'to',
#   'protect',
#   'myself',
#   'against',
#   'the',
#   'virus?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'other',
#   'if',
#   'i',
#   'am',
#   'sick',
#   'or',
#   'have',
#   'test',
#   'posit',
#   'with',
#   'the',
#   'coronavirus',
#   'disease?'],
#  ['can',
#   'someon',
#   'who',
#   'is',
#   'releas',
#   'from',
#   'covid-19',
#   'quarantin',
#   'still',
#   'spread',
#   'the',
#   'disease?'],
#  ['how',
#   'can',
#   'i',
#   'contribut',
#   'to',
#   'avoid',
#   'stigmatis',
#   'peopl',
#   'relat',
#   'to',
#   'covid-19?'],
#  ['nan'],
#  ['is', 'there', 'a', 'treatment', 'for', 'covid-19?'],
#  ['is', 'there', 'a', 'vaccin', 'against', 'covid-19?'],
#  ['must', 'i', 'fear', 'covid', '19?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'ensur',
#   'my',
#   'workplac',
#   'is',
#   'safe',
#   'for',
#   'me',
#   'and',
#   'my',
#   'colleague?'],
#  ['is',
#   'it',
#   'safe',
#   'to',
#   'use',
#   'public',
#   'transport',
#   '(dalla',
#   'dalla',
#   'or',
#   'matatu)',
#   'with',
#   'regard',
#   'to',
#   'covid-19?'],
#  ['can', 'i', 'attend', 'the', 'church', 'service?'],
#  ['are',
#   'african',
#   'less',
#   'at',
#   'risk',
#   'of',
#   'contract',
#   'the',
#   'covid-19',
#   'compar',
#   'to',
#   'other',
#   'races?'],
#  ['doe',
#   'eat',
#   'bush',
#   'meat',
#   'pose',
#   'a',
#   'risk',
#   'for',
#   'covid-19',
#   'infections?'],
#  ['are',
#   'patient',
#   'who',
#   'recov',
#   'from',
#   'covid-19',
#   'immun',
#   'against',
#   'the',
#   'virus?'],
#  ['how', 'safe', 'are', 'good', 'from', 'china?'],
#  ['can',
#   'i',
#   'get',
#   'covid-19',
#   'through',
#   'second-hand',
#   'cloth',
#   'from',
#   'overseas?'],
#  ['what',
#   'is',
#   'the',
#   'differ',
#   'between',
#   'the',
#   'averag',
#   'death',
#   'rate',
#   'among',
#   'confirm',
#   'case',
#   'and',
#   'the',
#   'overal',
#   'averag',
#   'death',
#   'rate?'],
#  ['what', 'is', 'a', 'coronavirus?'],
#  ['whi', 'is', 'it', 'call', 'a', 'coronavirus?'],
#  ['what', 'sever', 'diseas', 'are', 'caus', 'by', 'coronaviruses?'],
#  ['what', 'the', 'differ', 'between', 'coronavirus', 'and', 'covid-19?'],
#  ['what',
#   'symptom',
#   'do',
#   'coronavirus',
#   'typic',
#   'cause?',
#   'how',
#   'sever',
#   'are',
#   'the',
#   'symptom',
#   'in',
#   'the',
#   'current',
#   'outbreak?'],
#  ['doe', 'the', 'virus', 'affect', 'the', 'sens', 'of', 'taste?'],
#  ['whi', 'doe', 'covid-19', 'caus', 'short', 'of', 'breath?'],
#  ['is',
#   'the',
#   'loss',
#   'of',
#   'smell',
#   'an',
#   'earli',
#   'coronavirus',
#   'indicator?'],
#  ['even',
#   'for',
#   'peopl',
#   'who',
#   'are',
#   'mild',
#   'ill',
#   'or',
#   'moder',
#   'ill,',
#   'they',
#   'may',
#   'have',
#   'some',
#   'degre',
#   'of',
#   'impact',
#   'on',
#   'their',
#   'lung',
#   'that',
#   'could',
#   'caus',
#   'short',
#   'of',
#   'breath.',
#   'is',
#   'that',
#   'right?'],
#  ['when', 'and', 'how', 'should', 'i', 'seek', 'medic', 'attention?'],
#  ['how', 'are', 'coronavirus', 'transmit', 'between', 'people?'],
#  ['what',
#   'is',
#   'known',
#   'about',
#   'young',
#   'children',
#   'and',
#   'whether',
#   'they',
#   'are',
#   'carrier',
#   'and',
#   'can',
#   'transmit',
#   'the',
#   'virus?'],
#  ['what',
#   'percentag',
#   'of',
#   'the',
#   'popul',
#   'will',
#   'becom',
#   'infect',
#   'with',
#   'covid-19?'],
#  ['of',
#   'those',
#   'infected,',
#   'what',
#   'percentag',
#   'will',
#   'requir',
#   'hospitalization?',
#   'and',
#   'what',
#   'percentag',
#   'will',
#   'requir',
#   'care',
#   'in',
#   'an',
#   'intens',
#   'care',
#   'unit',
#   '(icu)?'],
#  ['are',
#   'there',
#   'differ',
#   '“species”',
#   'of',
#   'coronavirus',
#   'like',
#   'there',
#   'are',
#   'for',
#   'ebola?'],
#  ['what', 'doe', 'this', 'mean', 'for', 'a', 'vaccine?'],
#  ['when',
#   'peopl',
#   'are',
#   'asymptomatic,',
#   'can',
#   'they',
#   'spread',
#   'the',
#   'virus?'],
#  ['how',
#   'long',
#   'is',
#   'an',
#   'asymptomat',
#   'carrier',
#   'shed',
#   'the',
#   'virus?',
#   'can',
#   'they',
#   'have',
#   'it',
#   'for',
#   'life,',
#   'like',
#   'the',
#   'herp',
#   'virus?'],
#  ['what', 'doe', '“recovered”', 'mean?'],
#  ['what',
#   'is',
#   'the',
#   'possibl',
#   'of',
#   'reinfect',
#   'after',
#   'you',
#   'have',
#   'recov',
#   'from',
#   'covid-19?'],
#  ['is',
#   'there',
#   'a',
#   'differ',
#   'between',
#   'hospital-acquir',
#   'covid',
#   'and',
#   'community-acquir',
#   'covid?'],
#  ['is',
#   'there',
#   'evid',
#   'of',
#   'a',
#   'heighten',
#   'risk',
#   'to',
#   'pregnant',
#   'women?'],
#  ['what',
#   'is',
#   'known',
#   'about',
#   'how',
#   'this',
#   'virus',
#   'respond',
#   'to',
#   'warm',
#   'weather',
#   'and',
#   'the',
#   'potenti',
#   'for',
#   '“seasonality?”'],
#  ['there',
#   'have',
#   'been',
#   'more',
#   'case',
#   'in',
#   'the',
#   'northern',
#   'hemispher',
#   'than',
#   'the',
#   'southern',
#   'hemisphere.',
#   'what',
#   'doe',
#   'that',
#   'mean?'],
#  ['are', 'covid', 'toe', 'relat', 'to', 'blood', 'clotting?'],
#  ['what',
#   'make',
#   'this',
#   'upper',
#   'respiratori',
#   'infect',
#   'caus',
#   'by',
#   'an',
#   'rna',
#   'virus',
#   'ani',
#   'differ',
#   'from',
#   'hundr',
#   'of',
#   'other',
#   'upper',
#   'respiratori',
#   'infect',
#   'caus',
#   'by',
#   'rna',
#   'viruses?'],
#  ['are',
#   'some',
#   'group',
#   'at',
#   'a',
#   'higher',
#   'risk',
#   'for',
#   'sever',
#   'covid-19',
#   'illness?'],
#  ['are',
#   'there',
#   'option',
#   'for',
#   'support',
#   'senior',
#   'who',
#   "don't",
#   'have',
#   'onlin',
#   'access',
#   'for',
#   'get',
#   'groceri',
#   'delivered?'],
#  ['should',
#   'peopl',
#   'on',
#   'immunosuppress',
#   'drug',
#   'stop',
#   'take',
#   'their',
#   'medications?'],
#  ['will',
#   'peopl',
#   'who',
#   'are',
#   'on',
#   'these',
#   'drug',
#   'or',
#   'who',
#   'have',
#   'immunosuppress',
#   'condit',
#   'be',
#   'stuck',
#   'at',
#   'home',
#   'much',
#   'longer',
#   'than',
#   'other',
#   'who',
#   'may',
#   'be',
#   'abl',
#   'to',
#   'come',
#   'back',
#   'out',
#   'when',
#   'restrict',
#   'lift?'],
#  ['how',
#   'is',
#   'covid-19',
#   'is',
#   'impact',
#   'peopl',
#   'without',
#   'spleens?',
#   '(with',
#   'certain',
#   'bacteri',
#   'diseases,',
#   'peopl',
#   'without',
#   'spleen',
#   'can',
#   'get',
#   'veri',
#   'sever',
#   'infections.)'],
#  ['are',
#   'women',
#   'take',
#   'oral',
#   'contracept',
#   'more',
#   'at',
#   'risk',
#   'from',
#   'blood',
#   'clot',
#   'from',
#   'covid-19?'],
#  ['when', 'is', 'test', 'important?'],
#  ['what',
#   'doe',
#   'test',
#   'tell',
#   'us',
#   'about',
#   'the',
#   'rate',
#   'of',
#   'mortal',
#   'and',
#   'spread',
#   'of',
#   'the',
#   'virus?'],
#  ['whi',
#   "aren't",
#   'there',
#   'enough',
#   'test',
#   'avail',
#   'and',
#   'will',
#   'this',
#   'change?'],
#  ['whi',
#   'are',
#   'there',
#   'reagent',
#   'shortag',
#   'that',
#   'are',
#   'impact',
#   'testing?'],
#  ['is',
#   'the',
#   'current',
#   'spike',
#   'in',
#   'case',
#   'a',
#   'result',
#   'of',
#   'increas',
#   'test',
#   'or',
#   'becaus',
#   'the',
#   'virus',
#   'is',
#   'still',
#   'spreading?',
#   'when',
#   'can',
#   'we',
#   'expect',
#   'to',
#   'see',
#   'the',
#   'curv',
#   'flatten?'],
#  ['can',
#   'the',
#   'covid-19',
#   'test',
#   'tell',
#   'the',
#   'differ',
#   'between',
#   'someon',
#   'with',
#   'an',
#   'activ',
#   'infect',
#   'and',
#   'someon',
#   'who',
#   'was',
#   'infect',
#   'in',
#   'the',
#   'past?'],
#  ['what',
#   'is',
#   'the',
#   'differ',
#   'between',
#   'molecular',
#   'test',
#   'and',
#   'serolog',
#   'tests?',
#   'can',
#   'serolog',
#   'test',
#   'be',
#   'use',
#   'in',
#   'place',
#   'of',
#   'molecular',
#   'tests?'],
#  ['if',
#   'you',
#   'are',
#   'test',
#   'and',
#   'the',
#   'test',
#   'is',
#   'negative,',
#   'do',
#   'you',
#   'still',
#   'have',
#   'to',
#   'be',
#   'quarantined?'],
#  ['are', 'fals', 'negat', 'a', 'problem', 'with', 'covid', 'tests?'],
#  ['with',
#   'limit',
#   'test',
#   'available,',
#   'how',
#   'do',
#   'we',
#   'tell',
#   'peopl',
#   'to',
#   'assum',
#   'they',
#   'have',
#   'coronavirus,',
#   'or',
#   'have',
#   'been',
#   'expos',
#   'to',
#   'it,',
#   'without',
#   'panick',
#   'them?'],
#  ['should',
#   'we',
#   'be',
#   'test',
#   'first',
#   'respond',
#   'befor',
#   'they',
#   'start',
#   'their',
#   'work',
#   'day?'],
#  ['how',
#   'much',
#   'inform',
#   'about',
#   'the',
#   'movement',
#   'of',
#   'individu',
#   'who',
#   'test',
#   'posit',
#   'should',
#   'we',
#   'share,',
#   'and',
#   'how',
#   'do',
#   'we',
#   'avoid',
#   'caus',
#   'a',
#   'panic',
#   'by',
#   'peopl',
#   'think',
#   'they',
#   'may',
#   'have',
#   'been',
#   'exposed?'],
#  ['what',
#   'are',
#   'the',
#   'dispar',
#   'in',
#   'test',
#   'for',
#   'margin',
#   'communiti',
#   'and',
#   'how',
#   'can',
#   'we',
#   'address',
#   'them?'],
#  ['how', 'can', 'i', 'protect', 'myself', 'against', 'coronaviruses?'],
#  ['is', 'hand', 'sanit', 'effect', 'to', 'protect', 'against', 'coronavirus?'],
#  ['how', 'long', 'doe', 'the', 'virus', 'stay', 'on', 'your', 'clothes?'],
#  ['clean',
#   'produc',
#   'brought',
#   'home',
#   'from',
#   'the',
#   'groceri',
#   'store:',
#   'should',
#   'you',
#   'do',
#   'anyth',
#   'differ',
#   'or',
#   'use',
#   'ani',
#   'particular',
#   'clean',
#   'products?'],
#  ['is',
#   'takeout',
#   'food',
#   'safe?',
#   'what',
#   'precaut',
#   'should',
#   'peopl',
#   'take?'],
#  ['is', 'the', 'public', 'water', 'suppli', 'safe', 'from', 'the', 'virus?'],
#  ['if',
#   'two',
#   'peopl',
#   'are',
#   'positive,',
#   'can',
#   'they',
#   'quarantin',
#   'togeth',
#   'or',
#   'do',
#   'they',
#   'have',
#   'to',
#   'be',
#   'separated?'],
#  ['is',
#   'it',
#   'correct',
#   'that',
#   'if',
#   'someon',
#   'in',
#   'your',
#   'home',
#   'is',
#   'ill',
#   'then',
#   'you',
#   'should',
#   'also',
#   'be',
#   'stay',
#   'at',
#   'home?'],
#  ['can',
#   'you',
#   'avoid',
#   'the',
#   'virus',
#   'by',
#   'drink',
#   'warm',
#   'water',
#   'everi',
#   '15',
#   'minutes?'],
#  ['there',
#   'a',
#   'holding-your-breath',
#   'test',
#   'sweep',
#   'the',
#   'internet:',
#   'is',
#   'it',
#   'true',
#   'that',
#   'if',
#   'you',
#   'can',
#   'hold',
#   'your',
#   'breath,',
#   'you',
#   'know',
#   'that',
#   'you',
#   'do',
#   'or',
#   'you',
#   'do',
#   'not',
#   'have',
#   'covid-19?'],
#  ['should',
#   'the',
#   'general',
#   'public',
#   'cover',
#   'their',
#   'face',
#   'with',
#   'bandana',
#   'or',
#   'other',
#   'makeshift',
#   'masks?'],
#  ['is',
#   'there',
#   'offici',
#   'guidanc',
#   'on',
#   'the',
#   'efficaci',
#   'of',
#   'diy',
#   'face',
#   'mask',
#   'and',
#   'can',
#   'these',
#   'be',
#   'donat',
#   'for',
#   'use',
#   'in',
#   'health',
#   'care',
#   'settings?'],
#  ['are',
#   'there',
#   'accept',
#   'design',
#   'of',
#   'ppe',
#   'that',
#   'local',
#   'manufactur',
#   'and',
#   'hobbyist',
#   '3d',
#   'printer',
#   'can',
#   'creat',
#   'for',
#   'medic',
#   'staff?'],
#  ['if',
#   'someon',
#   'goe',
#   'for',
#   'a',
#   'jog',
#   'through',
#   'a',
#   'neighborhood',
#   'where',
#   'there',
#   'might',
#   'be',
#   'a',
#   'patient',
#   'with',
#   'novel',
#   'coronavirus,',
#   'are',
#   'they',
#   'at',
#   'risk?'],
#  ['how',
#   'should',
#   'i',
#   'help',
#   'a',
#   'friend,',
#   'neighbor,',
#   'or',
#   'famili',
#   'member',
#   'who',
#   'is',
#   'ill?'],
#  ['will', 'i', 'get', 'sick', 'if', 'i', 'help', 'care', 'for', 'them?'],
#  ['are', 'my', 'pet', 'at', 'risk', 'of', 'get', 'sick?'],
#  ['how',
#   'much',
#   'food',
#   'should',
#   'peopl',
#   'have',
#   'on',
#   'hand?',
#   'are',
#   'there',
#   'concern',
#   'about',
#   'the',
#   'food',
#   'suppli',
#   'at',
#   'this',
#   'point?'],
#  ['can',
#   'the',
#   'virus',
#   'travel',
#   'to',
#   'the',
#   'lower',
#   'lung',
#   'dure',
#   'deep',
#   'breath',
#   'exercises,',
#   'such',
#   'as',
#   'dure',
#   'yoga?'],
#  ['doe',
#   'a',
#   'person',
#   'blood',
#   'type',
#   'affect',
#   'how',
#   'infecti',
#   'or',
#   'sick',
#   'that',
#   'person',
#   'may',
#   'become?'],
#  ['can', 'you', 'get', 'covid-19', 'from', 'second-hand', 'smoke?'],
#  ['doe',
#   'prone',
#   'bodi',
#   'posit',
#   'help',
#   'veri',
#   'sever',
#   'ill',
#   'coronavirus',
#   'patient',
#   'in',
#   'the',
#   'intens',
#   'care',
#   'unit?'],
#  ['wet',
#   'market',
#   'in',
#   'china',
#   'are',
#   'wide',
#   'believ',
#   'to',
#   'be',
#   'a',
#   'sourc',
#   'of',
#   'new',
#   'infections,',
#   'includ',
#   'coronavirus.',
#   'should',
#   'they',
#   'be',
#   'shut',
#   'down?'],
#  ['can',
#   'peopl',
#   'expect',
#   'to',
#   'be',
#   'immun',
#   'onc',
#   "they'v",
#   'had',
#   'the',
#   'virus?',
#   'can',
#   'the',
#   'virus',
#   '“reactivate?”'],
#  ['are',
#   'peopl',
#   'who',
#   'are',
#   'sicker',
#   'like',
#   'to',
#   'be',
#   'more',
#   'immun',
#   'than',
#   'those',
#   'who',
#   "didn't",
#   'feel',
#   'ani',
#   'symptom',
#   'at',
#   'all?'],
#  ['is',
#   'it',
#   'possibl',
#   'that',
#   'some',
#   'peopl',
#   'may',
#   'be',
#   'expos',
#   'and',
#   'have',
#   'mild',
#   'ill',
#   'but',
#   'still',
#   'produc',
#   'antibodi',
#   'that',
#   'could',
#   'prevent',
#   'them',
#   'from',
#   'get',
#   'a',
#   'more',
#   'serious',
#   'infection?'],
#  ['mani',
#   'of',
#   'these',
#   'virus',
#   'come',
#   'from',
#   'bats,',
#   'but',
#   'bat',
#   'are',
#   'immun',
#   'to',
#   'them.',
#   'can',
#   'we',
#   'learn',
#   'someth',
#   'from',
#   'bat',
#   'that',
#   'would',
#   'help',
#   'us',
#   'fight',
#   'the',
#   'virus',
#   'in',
#   'humans?'],
#  ['what', 'treatment', 'are', 'there', 'for', 'coronaviruses?'],
#  ['what',
#   'progress',
#   'is',
#   'be',
#   'made',
#   'on',
#   'therapi',
#   'or',
#   'treatment',
#   'for',
#   'covid-19?'],
#  ['is',
#   'there',
#   'evid',
#   'for',
#   'use',
#   'hydroxychloroquin',
#   'as',
#   'a',
#   'treatment',
#   'for',
#   'covid-19?'],
#  ['we',
#   'have',
#   'a',
#   'new',
#   'flu',
#   'vaccin',
#   'everi',
#   'year',
#   'with',
#   'a',
#   'new',
#   'strain.',
#   'whi',
#   'is',
#   'it',
#   'so',
#   'hard',
#   'to',
#   'get',
#   'a',
#   'coronavirus',
#   'vaccine?'],
#  ['is',
#   'interferon',
#   'alfa',
#   '2b',
#   'an',
#   'effect',
#   'treatment?',
#   'should',
#   'we',
#   'be',
#   'encourag',
#   'our',
#   'medic',
#   'communiti',
#   'to',
#   'obtain',
#   'this?'],
#  ['what', 'are', 'random', 'control', 'trials?'],
#  ['whi',
#   'is',
#   'the',
#   'world',
#   'respons',
#   'to',
#   'covid-19',
#   'so',
#   'much',
#   'greater',
#   'than',
#   'the',
#   'respons',
#   'to',
#   'other',
#   'outbreak',
#   'like',
#   'h1n1',
#   'or',
#   'sars?'],
#  ['what',
#   'metric',
#   'should',
#   'citi',
#   'be',
#   'look',
#   'at',
#   'to',
#   'understand',
#   'the',
#   'real-tim',
#   'spread',
#   'and',
#   'anticip',
#   'the',
#   'time',
#   'of',
#   'the',
#   'surge?'],
#  ['for',
#   'busi',
#   'that',
#   'remain',
#   'open,',
#   'what',
#   'are',
#   'best',
#   'practic',
#   'they',
#   'should',
#   'be',
#   'use',
#   'to',
#   'stop',
#   'the',
#   'spread?'],
#  ['what',
#   'should',
#   'we',
#   'do',
#   'to',
#   'protect',
#   'employe',
#   'at',
#   'busi',
#   'that',
#   'are',
#   'still',
#   'open,',
#   'like',
#   'groceri',
#   'stores,',
#   'hotels,',
#   'and',
#   'restaurants?'],
#  ['doe',
#   'the',
#   'scienc',
#   'support',
#   'limit',
#   'the',
#   'number',
#   'of',
#   'peopl',
#   'in',
#   'groceri',
#   'store',
#   'at',
#   'one',
#   'time?'],
#  ['how',
#   'do',
#   'we',
#   'get',
#   'through',
#   'to',
#   'the',
#   'youth',
#   'who',
#   'feel',
#   'they',
#   'are',
#   'immun',
#   'to',
#   'the',
#   'diseas',
#   'or',
#   'not',
#   'affect',
#   'by',
#   'it?'],
#  ['whi',
#   "aren't",
#   'we',
#   'see',
#   'human',
#   'temperatur',
#   'monitor',
#   'in',
#   'public',
#   'place',
#   'like',
#   'airports,',
#   'hospitals,',
#   'groceri',
#   'stores,',
#   'warehouses,',
#   'etc.?'],
#  ['are', 'resid', 'of', 'homeless', 'shelter', 'a', 'vulner', 'population?'],
#  ['what', 'is', 'a', 'coronavirus?'],
#  ['what', 'is', 'a', 'coronavirus?'],
#  ['what', 'is', 'covid-19?'],
#  ['what', 'are', 'the', 'symptom', 'of', 'covid-19?'],
#  ['what', 'are', 'the', 'symptom', 'of', 'covid-19?'],
#  ['what', 'are', 'the', 'symptom', 'of', 'covid-19?'],
#  ['what', 'are', 'the', 'symptom', 'of', 'covid-19?'],
#  ['how', 'doe', 'covid-19', 'spread?'],
#  ['how', 'doe', 'covid-19', 'spread?'],
#  ['can',
#   'the',
#   'virus',
#   'that',
#   'caus',
#   'covid-19',
#   'be',
#   'transmit',
#   'through',
#   'the',
#   'air?'],
#  ['can',
#   'covid-19',
#   'be',
#   'caught',
#   'from',
#   'a',
#   'person',
#   'who',
#   'has',
#   'no',
#   'symptoms?'],
#  ['can',
#   'covid-19',
#   'be',
#   'caught',
#   'from',
#   'a',
#   'person',
#   'who',
#   'has',
#   'no',
#   'symptoms?'],
#  ['can',
#   'i',
#   'catch',
#   'covid-19',
#   'from',
#   'the',
#   'fece',
#   'of',
#   'someon',
#   'with',
#   'the',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'and',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'and',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'and',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'and',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'and',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'and',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'and',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'to',
#   'protect',
#   'myself',
#   'andprotect',
#   'measur',
#   'for',
#   'person',
#   'who',
#   'are',
#   'in',
#   'or',
#   'have',
#   'recent',
#   'visit',
#   '(past',
#   '14',
#   'days)',
#   'area',
#   'where',
#   'covid-19',
#   'is',
#   'spread',
#   'prevent',
#   'the',
#   'spread',
#   'of',
#   'disease?'],
#  ['protect',
#   'measur',
#   'for',
#   'person',
#   'who',
#   'are',
#   'in',
#   'or',
#   'have',
#   'recent',
#   'visit',
#   '(past',
#   '14',
#   'days)',
#   'area',
#   'where',
#   'covid-19',
#   'is',
#   'spread'],
#  ['how', 'like', 'am', 'i', 'to', 'catch', 'covid-19?'],
#  ['how', 'like', 'am', 'i', 'to', 'catch', 'covid-19?'],
#  ['how', 'like', 'am', 'i', 'to', 'catch', 'covid-19?'],
#  ['should', 'i', 'worri', 'about', 'covid-19'],
#  ['should', 'i', 'worri', 'about', 'covid-19'],
#  ['who', 'is', 'at', 'risk', 'of', 'develop', 'sever', 'illness?'],
#  ['are',
#   'antibiot',
#   'effect',
#   'in',
#   'prevent',
#   'or',
#   'treat',
#   'the',
#   'covid-19?'],
#  ['are',
#   'antibiot',
#   'effect',
#   'in',
#   'prevent',
#   'or',
#   'treat',
#   'the',
#   'covid-19?'],
#  ['are',
#   'there',
#   'ani',
#   'medicin',
#   'or',
#   'therapi',
#   'that',
#   'can',
#   'prevent',
#   'or',
#   'cure',
#   'covid-19?'],
#  ['are',
#   'there',
#   'ani',
#   'medicin',
#   'or',
#   'therapi',
#   'that',
#   'can',
#   'prevent',
#   'or',
#   'cure',
#   'covid-19?'],
#  ['is',
#   'there',
#   'a',
#   'vaccine,',
#   'drug',
#   'or',
#   'treatment',
#   'for',
#   'covid-19?'],
#  ['is',
#   'there',
#   'a',
#   'vaccine,',
#   'drug',
#   'or',
#   'treatment',
#   'for',
#   'covid-19?'],
#  ['is',
#   'there',
#   'a',
#   'vaccine,',
#   'drug',
#   'or',
#   'treatment',
#   'for',
#   'covid-19?'],
#  ['is',
#   'there',
#   'a',
#   'vaccine,',
#   'drug',
#   'or',
#   'treatment',
#   'for',
#   'covid-19?'],
#  ['is', 'covid-19', 'the', 'same', 'as', 'sars?'],
#  ['is', 'covid-19', 'the', 'same', 'as', 'sars?'],
#  ['should', 'i', 'wear', 'a', 'mask', 'to', 'protect', 'myself'],
#  ['should', 'i', 'wear', 'a', 'mask', 'to', 'protect', 'myself'],
#  ['should', 'i', 'wear', 'a', 'mask', 'to', 'protect', 'myself'],
#  ['how',
#   'to',
#   'put',
#   'on,',
#   'use,',
#   'take',
#   'off',
#   'and',
#   'dispos',
#   'of',
#   'a',
#   'mask?'],
#  ['how',
#   'to',
#   'put',
#   'on,',
#   'use,',
#   'take',
#   'off',
#   'and',
#   'dispos',
#   'of',
#   'a',
#   'mask?'],
#  ['how', 'long', 'is', 'the', 'incub', 'period', 'for', 'covid-19?'],
#  ['how', 'long', 'is', 'the', 'incub', 'period', 'for', 'covid-19?'],
#  ['can',
#   'human',
#   'be',
#   'infect',
#   'with',
#   'the',
#   'covid-19',
#   'from',
#   'an',
#   'anim',
#   'source?'],
#  ['can',
#   'human',
#   'be',
#   'infect',
#   'with',
#   'the',
#   'covid-19',
#   'from',
#   'an',
#   'anim',
#   'source?'],
#  ['can',
#   'human',
#   'be',
#   'infect',
#   'with',
#   'the',
#   'covid-19',
#   'from',
#   'an',
#   'anim',
#   'source?'],
#  ['can',
#   'human',
#   'be',
#   'infect',
#   'with',
#   'the',
#   'covid-19',
#   'from',
#   'an',
#   'anim',
#   'source?'],
#  ['can',
#   'human',
#   'be',
#   'infect',
#   'with',
#   'the',
#   'covid-19',
#   'from',
#   'an',
#   'anim',
#   'source?'],
#  ['can', 'i', 'catch', 'covid-19', 'from', 'my', 'pet?'],
#  ['can', 'i', 'catch', 'covid-19', 'from', 'my', 'pet?'],
#  ['how', 'long', 'doe', 'the', 'virus', 'surviv', 'on', 'surfaces?'],
#  ['how', 'long', 'doe', 'the', 'virus', 'surviv', 'on', 'surfaces?'],
#  ['how', 'long', 'doe', 'the', 'virus', 'surviv', 'on', 'surfaces?'],
#  ['is',
#   'it',
#   'safe',
#   'to',
#   'receiv',
#   'a',
#   'packag',
#   'from',
#   'ani',
#   'area',
#   'where',
#   'covid-19',
#   'has',
#   'been',
#   'reported?'],
#  ['is', 'there', 'anyth', 'i', 'should', 'not', 'do?'],
#  ['is', 'there', 'anyth', 'i', 'should', 'not', 'do?'],
#  ['is', 'there', 'anyth', 'i', 'should', 'not', 'do?'],
#  ['is', 'the', 'sourc', 'caus', 'covid-19', 'known?'],
#  ['how', 'did', 'the', 'first', 'human', 'sars-cov-2', 'infect', 'occur?'],
#  ['how', 'did', 'the', 'first', 'human', 'sars-cov-2', 'infect', 'occur?'],
#  ['how', 'did', 'the', 'first', 'human', 'sars-cov-2', 'infect', 'occur?'],
#  ['is', 'covid-19', 'airborne?'],
#  ['are', 'pregnant', 'women', 'at', 'higher', 'risk', 'from', 'covid-19?'],
#  ['are', 'pregnant', 'women', 'at', 'higher', 'risk', 'from', 'covid-19?'],
#  ["i'm",
#   'pregnant.',
#   'how',
#   'can',
#   'i',
#   'protect',
#   'myself',
#   'against',
#   'covid-19?'],
#  ["i'm",
#   'pregnant.',
#   'how',
#   'can',
#   'i',
#   'protect',
#   'myself',
#   'against',
#   'covid-19?'],
#  ['should', 'pregnant', 'women', 'be', 'test', 'for', 'covid-19?'],
#  ['can',
#   'covid-19',
#   'be',
#   'pass',
#   'from',
#   'a',
#   'woman',
#   'to',
#   'her',
#   'unborn',
#   'baby?'],
#  ['what',
#   'care',
#   'should',
#   'be',
#   'avail',
#   'dure',
#   'pregnanc',
#   'and',
#   'childbirth?'],
#  ['do',
#   'pregnant',
#   'women',
#   'with',
#   'suspect',
#   'or',
#   'confirm',
#   'covid-19',
#   'need',
#   'to',
#   'give',
#   'birth',
#   'by',
#   'ceasarean',
#   'section?'],
#  ['can', 'women', 'with', 'covid-19', 'breastfeed?'],
#  ['can',
#   'i',
#   'touch',
#   'and',
#   'hold',
#   'my',
#   'newborn',
#   'babi',
#   'if',
#   'i',
#   'have',
#   'covid-19?'],
#  ['how', 'are', 'covid-19', 'and', 'influenza', 'virus', 'similar?'],
#  ['how', 'are', 'covid-19', 'and', 'influenza', 'virus', 'similar?'],
#  ['how', 'are', 'covid-19', 'and', 'influenza', 'virus', 'different?'],
#  ['how', 'are', 'covid-19', 'and', 'influenza', 'virus', 'different?'],
#  ['how', 'are', 'covid-19', 'and', 'influenza', 'virus', 'different?'],
#  ['what',
#   'medic',
#   'intervent',
#   'are',
#   'avail',
#   'for',
#   'covid-19',
#   'and',
#   'influenza',
#   'viruses?'],
#  ['are',
#   'smoker',
#   'and',
#   'tobacco',
#   'user',
#   'at',
#   'higher',
#   'risk',
#   'of',
#   'covid-19',
#   'infection?'],
#  ['are',
#   'smoker',
#   'and',
#   'tobacco',
#   'user',
#   'at',
#   'higher',
#   'risk',
#   'of',
#   'covid-19',
#   'infection?'],
#  ['how',
#   'larg',
#   'doe',
#   'a',
#   'meet',
#   'or',
#   'event',
#   'need',
#   'to',
#   'be',
#   'in',
#   'order',
#   'to',
#   'be',
#   'a',
#   '“mass',
#   'gathering”?'],
#  ['how',
#   'larg',
#   'doe',
#   'a',
#   'meet',
#   'or',
#   'event',
#   'need',
#   'to',
#   'be',
#   'in',
#   'order',
#   'to',
#   'be',
#   'a',
#   '“mass',
#   'gathering”?'],
#  ['doe',
#   'who',
#   'recommend',
#   'that',
#   'all',
#   'intern',
#   'mass',
#   'gather',
#   'be',
#   'cancel',
#   'becaus',
#   'of',
#   'covid-19?']]

# %%
train_w2v = Word2Vec(splitted,min_count=1,size=100, workers=4)

# %%
avg_data = []
for row in splitted:
    vec = np.zeros(100)
    count = 0
    for word in row:
        try:
            vec += train_w2v[word]
            count += 1
        except:
            pass
    avg_data.append(vec/count)
# Out:
# C:\Users\uroot\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys

# %%
avg_data = np.array(avg_data)

# %%
for i,(q , a) in enumerate(zip(QA['q'],QA['a'])):
    QA_dict[i] = [q,a]

# %%
def wv_test(q):
    tq = [q]
    tq = clean(tq)
    tq = clean_col(tq)
    splitted_test = []
    for row in tq: 
        splitted_test.append([word for word in row.split()]) 
    avg_data_test = []
    for row in splitted_test:
        vec = np.zeros(100)
        count = 0
        for word in row:
            try:
                vec += train_w2v[word]
                count += 1
            except:
                pass
        avg_data_test.append(vec/count)
    return np.array(avg_data_test)

# %%
QA['q'].sample(20)
# Out:
# 4     What symptoms do coronaviruses typically cause...
# 23                       How can I help protect myself?
# 77    How are COVID-19 and influenza viruses different?
# 68    Is it possible to have the flu and COVID-19 at...
# 74    Is there evidence for using hydroxychloroquine...
# 7     Is the loss of smell an early coronavirus indi...
# 60    How did the first human SARS-CoV-2 infections ...
# 60    What cleaning products should I use to protect...
# 19    What can I do to protect myself and prevent th...
# 21    Is there evidence of a heightened risk to preg...
# 12                 Why are we seeing a rise in cases?\n
# 89                  What is CDC doing about COVID-19?\n
# 32    Are the symptoms of COVID-19 di erent in child...
# 6     Is there any concern mosquitoes carying the vi...
# 91    Is it safe to vacuum in a school, business, or...
# 24            Are COVID toes related to blood clotting?
# 7                             How does COVID-19 spread?
# 82    Does the science support limiting the number o...
# 29    Should contact lens wearers take special preca...
# 58    If someone goes for a jog through a neighborho...
# Name: q, dtype: object

# %%
while True:
    q = input("Q: ")
    q = wv_test(q)
    ranks = np.array([cosine_similarity(q.reshape(1,100),avg_data[i].reshape(1,100)) for i in range(QA.shape[0])]).reshape(QA.shape[0],1)
    loc = np.argmax(ranks)  
    a = QA_dict[loc][1]
    print("A: ",a)
# Out:
# Q: can animals spread the virus
# C:\Users\uroot\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# A:  At this time, CDC has no data to suggest that this new coronavirus or other similar coronaviruses are spread by
# mosquitoes or ticks. The main way that COVID-19 spreads is from person to person. See How Coronavirus Spreads for
# more information.
#
# Q: can the virus cause depression
# C:\Users\uroot\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# A:  At this time, CDC has no data to suggest that this new coronavirus or other similar coronaviruses are spread by
# mosquitoes or ticks. The main way that COVID-19 spreads is from person to person. See How Coronavirus Spreads for
# more information.
#
# Q: when will it end
# C:\Users\uroot\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# A:  Testing is particularly important for people who are seriously ill. Knowing the diagnosis is important for clinical care, allows health care workers to protect themselves, and is necessary for research into treatments.
#
# For people who are mildly or moderately ill, testing can help assure that they isolate themselves and alert people they have come in contact with of the potential need for quarantine. By quickly identifying individuals who are sick and isolating them, public health authorities can reduce the spread of the novel coronavirus.
#
# To assure both that tests are available for those who need them and that the health professionals are prepared to do the test safely, adequate safety equipment is essential. Not every clinic or medical office will conduct the testing. Physicians and public health authorities should direct people to where they can be tested. Given the limited availability of testing, there is much less urgency to test people who are feeling well.
#
# Also, wherever possible, people should not just show up at emergency departments for testing, in order to reduce the demand on hospitals as well as to protect themselves and others. It is much better to call ahead, determine that testing is appropriate and available, and follow instructions on where and when to go.
# Q: does it kill people
# C:\Users\uroot\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# A:  The virus that causes COVID-19 is thought to spread mainly from person to person, mainly through respiratory
# droplets produced when an infected person coughs or sneezes. These droplets can land in the mouths or noses of
# people who are nearby or possibly be inhaled into the lungs. Spread is more likely when people are in close contact
# with one another (within about 6 feet).
# COVID-19 seems to be spreading easily and sustainably in the community (“community spread”) in many a ected
# geographic areas. Community spread means people have been infected with the virus in an area, including some who
# are not sure how or where they became infected.
#
# Q: symptoms
# C:\Users\uroot\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# A:  Common signs of infection include runny nose, cough, fever, sore throat, and shortness of breath. In more severe cases, infection can cause pneumonia, severe acute respiratory syndrome, kidney failure, and even death.
# Q:  What is CDC doing about COVID-19
# C:\Users\uroot\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# A:  CDC is working with other federal partners in a whole-of-government response. This is an emerging, rapidly evolving
# situation and CDC will continue to provide updated information as it becomes available. CDC works 24/7 to protect
# people’s health. More information about CDC’s response to COVID-19 is available online.
#
# Q: do we have treatment?
# C:\Users\uroot\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# A:  People who have symptoms should assume they have it, isolate themselves from other people, talk to people they may have exposed in the days prior to experiencing symptoms, and recommend that those contacts self-quarantine. Mayors should reinforce this message. Having a call center or using 311 for coronavirus response could help mayors and public health officials provide these messages. Such a system can also be a way to keep track of the epidemic. If you give people experiencing symptoms the option to go online or call for help with food delivery or other services, you can log them into a database, and, to the extent that the health department is able, do contact tracing, make referrals, and offer support.
# Q: treatment?
# C:\Users\uroot\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# A:  Every viral disease needs to be taken seriously and COVID-19 is highly contagious. Therefore, it can spread rapidly and infect many people in a short period of time. But, the symptoms of COVID-19 are in most cases mild. Many patients will never even see a doctor. With about 4 % the average death rate for COVID-19 is also rather low compared to other diseases that we are facing in the region. For comparison: The death rate for measles outbreaks of for the Ebola Virus Disease can be above 60 % and up to 100 % of people infected with Rabies will die.
#
# Another example: In China, with a total population of more than 1,4 billion people, only about 80,000 cases of COVID-19 were confirmed.
# Q: jogging
# C:\Users\uroot\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# A:  No. The majority of transmissions of this virus occur through droplet transmission. This means that a sick patient who coughs or sneezes is expelling virus through droplets that don’t travel that far. They tend to fall to surfaces within a six-foot distance. If you touch a surface that is contaminated with droplets from someone who has coughed or sneezed on it and then you touch your eyes or nose or mouth, you could potentially become infected that way.
# Q: pregnant women
# C:\Users\uroot\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# A:  Testing protocols and eligibility vary depending on where you live.
# Q: Should I stay inside the house
# C:\Users\uroot\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# A:  It is very difficult to accurately predict the surge without having sufficient testing capacity for the population. Depending on the scale of testing in the area, cities may be able to look at test results to understand the likely surge in patients coming in the ensuing 2–4 weeks. Cities should also closely monitor the hospital system to assess the number of hospitalized and ICU patients, as well as the doubling time in the growth of the number of these patients. If there is a single call center for people with symptoms, the number of calls should be tracked as one measure to watch. There are other emerging sources of data, such as fevers reported by companies that make internet-enabled thermometers.
# Q: Should I stay inside the house
# C:\Users\uroot\anaconda3\envs\ml\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# A:  It is very difficult to accurately predict the surge without having sufficient testing capacity for the population. Depending on the scale of testing in the area, cities may be able to look at test results to understand the likely surge in patients coming in the ensuing 2–4 weeks. Cities should also closely monitor the hospital system to assess the number of hospitalized and ICU patients, as well as the doubling time in the growth of the number of these patients. If there is a single call center for people with symptoms, the number of calls should be tracked as one measure to watch. There are other emerging sources of data, such as fevers reported by companies that make internet-enabled thermometers.

# %%
jogging
